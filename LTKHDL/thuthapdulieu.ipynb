# %% [markdown]
# <h1><b>PHẦN 1: QUY TRÌNH KHOA HỌC DỮ LIỆU</b></h1>

# %% [markdown]
# <h1><b>A. Thu thập dữ liệu (Data collection)</b></h1>

# %% [markdown]
# ## Import những thư viện cần thiết

# %%
import scrapy
import pandas as pd
import json
import numpy as np

# %% [markdown]
# ## Tạo một project mới với scrapy
#
# Bắt đầu tạo một project mới với scrapy với tên gọi là <b>"colect_data"</b>.

# %%
# !scrapy startproject collect_data
# Out:
# Error: Module 'collect_data' already exists

# %%
cd collect_data/collect_data
# Out:
# [WinError 3] The system cannot find the path specified: 'collect_data/collect_data'
# c:\Users\KHUONG\OneDrive\Documents\GitHub\LT_LT4KHDL\LTKHDL\collect_data\collect_data

# %% [markdown]
# Sau khi tạo xong project với scrapy, ta cần tạo một file có tên <b>collect_data.py</b> vào đường dẫn sau <b>collect_data/collect_data/spiders/collect_data.py</b>. Su đó chạy lệnh sau để thu thập dữ liệu.

# %%
# !scrapy crawl Get_Data -o dataset/info.csv
# Out:
# 2022-12-21 17:13:05 [scrapy.utils.log] INFO: Scrapy 2.6.3 started (bot: collect_data)
# 2022-12-21 17:13:05 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Windows-10-10.0.22621-SP0
# 2022-12-21 17:13:05 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'collect_data',
#  'NEWSPIDER_MODULE': 'collect_data.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['collect_data.spiders']}
# 2022-12-21 17:13:05 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-12-21 17:13:05 [scrapy.extensions.telnet] INFO: Telnet Password: 0e66b89db8c308b9
# 2022-12-21 17:13:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-12-21 17:13:06 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-12-21 17:13:06 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-12-21 17:13:06 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-12-21 17:13:06 [scrapy.core.engine] INFO: Spider opened
# 2022-12-21 17:13:06 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-12-21 17:13:06 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2022-12-21 17:13:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/robots.txt> (referer: None)
# 2022-12-21 17:13:09 [filelock] DEBUG: Attempting to acquire lock 2222262292912 on C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-21 17:13:09 [filelock] DEBUG: Lock 2222262292912 acquired on C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-21 17:13:09 [filelock] DEBUG: Attempting to release lock 2222262292912 on C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-21 17:13:09 [filelock] DEBUG: Lock 2222262292912 released on C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-21 17:13:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam-it?page=1> (referer: None)
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/senior-business-analyst-chuyen-vien-phan-tich-nghiep-vu/895551.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/senior-business-analyst-chuyen-vien-phan-tich-nghiep-vu/895551.html?ta_source=JobSearchList>
#
# {'Title': 'Business Analyst', 'Company': 'Asilla Việt Nam', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/01/2023\n', 'Salary': '\nTới 1,400 USD\n', 'Quantity': '5 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '3 năm', 'DiaChi': ['Cầu Giấy', 'Hà Nội'], 'Skill': [], 'JobData': ['- Collaborate with Product Manager to understand the demands from the market and draft tasks based on it\n', '-\tCollaborate with development team members to understand technical solutions\n', '-\tMake detailed requirements, propose suitable solutions based on user perspective understanding.\n', '-\tKeep up to date on business domain knowledge of the company\n', '-\tKeep up to date on the latest applications of IT and AI technologies', '-\tAt least 3 years of working experience in BA position', '-\tProduct and market mindset\n', '-\tNeed strong analytical skills to create reports and documents\n', '-\tThe ability to manage multiple projects from beginning to completion.\n', '- Good written and verbal communication skills for working with all stakeholders.\n', '- The ability to understand the team’s challenges and develop solutions.\n', '- Must be familiar with various types of project management (and business analysis) software. Proficiency in spreadsheets is also important.\n', '- Must be familiar with wireframe design tools (like Figma)\n', '-\tBusiness English', '- Competitive salary: upto $1800\n', '- 14 months salary a year\n', '-\tOpportunity to receive bonus shares.\n', '-\tTo fully participate in the regimes prescribed by the State such as: social insurance, health insurance, unemployment insurance, annual leave.\n', '-\tBe trained and work directly with experienced experts in the field of AI.\n', '-\tHave the opportunity to do challenging things, develop your full potential\n', '-\tParticipate in team building sessions, company travel, have fun monthly with the Company;\n', '-\tEnjoy full benefits (Happiness, birthday...);\n', '-\tYoung, comfortable working environment, dynamic startup spirit.', '\n']}
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/unity-developer/278444.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/nhan-vien-trien-khai-du-an-phan-mem-it-support/656546.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/chuyen-vien-nhan-su-cb-phu-trach-lam-luong/896841.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/java-developer/351060.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/unity-developer/278444.html?ta_source=JobSearchList>
#
# {'Title': 'Unity Developer', 'Company': 'Công ty Cổ phần Skynet Việt Nam', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 20/01/2023\n', 'Salary': '\n8-30 triệu\n', 'Quantity': '3 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': 'Dưới 1 năm', 'DiaChi': ['Hà Nội', 'Nam Từ Liêm'], 'Skill': ['C#', 'C++', 'Unity'], 'JobData': ['- Xây dựng và phát triển các dự án Game mobile trên nền tảng Unity', '- Phối hợp với các thành viên khác trong team (Game Designer, Artist …) để xây dựng ý tưởng, đưa ra các giải pháp kỹ thuật để tạo được sản phẩm tốt nhất', '- Xây dựng và duy trì code hiệu quả, có thể tái sử dụng', '- Nâng cấp và tối ưu các sản phẩm của công ty.', '- Có kinh nghiệm lập trình Unity ít nhất 6 tháng trở lên, có sản phẩm demo', '- Yêu thích làm Game', '- Thành thạo Unity', '- Có tư duy lập trình và tư duy hệ thống tốt', '- Chủ động trong công việc, có tinh thần trách nhiệm cao, thái độ cầu tiến ham học hỏi.', '\xa0', '- Mức lương thỏa thuận hấp dẫn, tương xứng với năng lực và kinh nghiệm làm việc', '- Thử việc 2 tháng, nhận 100% lương', '- Thưởng không giới hạn tùy theo doanh thu sản phẩm và mức độ đóng góp trong dự án', '- Môi trường làm việc trẻ trung, năng động, sáng tạo và nhiệt huyết', '- Review lương 2 lần/năm hoặc tùy theo mức độ phát triển của bản thân', '- Chế độ đầy đủ theo luật BHXH, nghỉ lễ Tết, 12 ngày phép/năm, lương thưởng cuối năm.', '- Văn phòng rộng rãi, tiện nghi đảm bảo điều kiện làm việc tốt nhất.', '- Du lịch thường niên, được tham gia vào các hoạt động team building cực kỳ bổ ích.', '- Tặng quà vào các dịp sinh nhật, lễ Tết.', '- Tham gia hoạt động thể thao hàng tuần cùng công ty.']}
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/backend-developer-php-python-java/896950.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/nhan-vien-it-tai-khach-san/896579.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/net-developer/896817.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/nhan-vien-trien-khai-du-an-phan-mem-it-support/656546.html?ta_source=JobSearchList>
#
# {'Title': 'IT Support', 'Company': 'CÔNG TY TNHH MICROTEC VIỆT NAM', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '2 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Nam', 'KinhNghiem': '1 năm', 'DiaChi': ['Hà Nội', 'Hoàn Kiếm'], 'Skill': ['IT Helpdesk', 'Windows Server'], 'JobData': ['- Tham gia các dự án triển khai phần mềm hiện đại, tiên tiến nhất hiện nay cho hệ thống ATM/KIOS/digital banking của các tổ chức tài chính/ ngân hàng trong và ngoài nước.\xa0', '- Xây dựng tiến độ thực hiện dự án, giám sát và phối hợp với các nhóm liên quan để đảm bảo tiến độ và chất lượng của dự án.\xa0', '- Đào tạo, chuyển giao các giải pháp, ứng dụng và thiết bị do công ty cung cấp cho khách hàng.\xa0', '- Xử lý, khắc phục sự cố cho các ứng dụng và thiết bị tại máy ATM.', '- \xa0Tốt nghiệp đại học ngành Công nghệ thông tin, tin học: chuyên ngành phần mềm, hệ thống thông tin hoặc hệ thống mạng', '- \xa0Có kiến thức và kinh nghiệm cài đặt cấu hình xử lý trên các hệ điều hành: Windows, Window server.\xa0', '- Có hiểu biết cơ bản về hệ thống mạng, hạ tầng máy tính. Khả năng đọc, hiểu các lỗi từ log và system event log trong window.', '- Có kinh nghiệm về cài đặt cơ sở dữ liệu: Oracle, Microsoft SQL Server,... là một lợi thế', '- Trình độ tiếng Anh: có khả năng đọc hiểu tài liệu chuyên ngành CNTT (bắt buộc), và giao tiếp tốt là lợi thế.', '- Ưu tiên ứng viên có kinh nghiệm ở vị trí IT helpdesk.\xa0', '- Nhận các sinh viên mới tốt nghiệp có kiến thức và kỹ năng tốt.', '- Mức lương cạnh tranh và hấp dẫn dựa trên năng lực và kinh nghiệm;\xa0', '- Cơ chế xét duyệt tăng lương hàng năm dựa trên điểm KPI và thưởng 2 lần / năm;\xa0', '- Làm việc trong môi trường chuyên nghiệp, có cơ hội phát triển bản thân trong lĩnh vực tài chính ngân hàng;\xa0', '- Các chế độ khác:\xa0', '• Bảo hiểm toàn diện (BH tai nạn và BH sức khỏe Liberty)\xa0', '• Team building hàng năm\xa0', '• Nghỉ phép 14 ngày / năm, nghỉ hè', '• Nhiều hoạt động tập thể hấp dẫn cho nhân viên và gia đình']}
# 2022-12-21 17:13:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/chuyen-vien-nhan-su-cb-phu-trach-lam-luong/896841.html?ta_source=JobSearchList>
#
# {'Title': 'Nhân Sự', 'Company': 'Công Ty Cổ Phần Công Nghệ VMO Holdings', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/01/2023\n', 'Salary': '\nTrên 15 triệu\n', 'Quantity': '1 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '3 năm', 'DiaChi': ['Hà Nội'], 'Skill': [], 'JobData': ['- Trực tiếp thực hiện tính lương cho CBNV công ty', '- Tổng hợp báo cáo và phân tích các dữ liệu về tiền lương, thưởng, chính sách và đưa ra các đánh giá.', '- Thực hiện các công việc chính sách Công ty: BHXH, phúc lợi, ...', '- Phối hợp với phòng Tài chính Kế toán quản lý chỉ số quỹ lương.', '- Quản lý hồ sơ, quan hệ lao động', '- Theo dõi tăng giảm bảo hiểm xã hội của công ty', '• Tốt nghiệp Đại học các chuyên ngành: Quản trị nhân lực, Quản trị kinh doanh, Luật hoặc các ngành liên quan.', '• Có tư duy hệ thống, logic và tổng hợp và phân tích số liệu.', '• Cẩn thận, tỉ mỉ, chi tiết, có trách nhiệm.', '• Kỹ năng sử dụng Excel tốt.', '• Kỹ năng cập nhật và áp dụng luật lao động.', '• Ứng viên có kiến thức tốt về mảng nhân sự, C&B', '• Am hiểu về luật lao động, thuế TNCN…', '• Review lương từ 1-2 lần/năm. Chính sách thưởng tháng lương 13. Thưởng lễ Tết, 2/9, sinh nhật công ty,…', '• Chế độ du lịch nghỉ mát (gói 5 triệu/ người), teambuilding (2 -3 lần/năm).', '• Tham gia BHXH đầy đủ, thm khám sức khỏe định kỳ tối thiểu 1 lần/năm tại các bệnh viện hàng đầu', '• Chính sách thăm hỏi toàn diện cho nhân sự và người thân: sinh nhật, kết hôn, sinh con, ốm đau,…', '• Các hoạt động thể thao, văn hóa đa dạng và phong phú: CLB đá bóng, đạp xe, cầu lông,…\xa0', '• Phụ cấp đứng lớp, cùng các giải thưởng Đào tạo: Ngôi sao học tập tháng, Gương mặt giảng viên tiêu biểu, gương mặt học tập năm, nhuận bút…']}
# 2022-12-21 17:13:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/java-developer/351060.html?ta_source=JobSearchList>
#
# {'Title': 'Java Developer', 'Company': 'Công ty TNHH phần mềm Kaopiz', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '1 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '1 năm', 'DiaChi': ['Hà Nội'], 'Skill': ['Java', 'Spring', 'Spring Boot'], 'JobData': ['Tham gia các dự án sử dụng ngôn ngữ lập trình Java cùng framework SpringBoot và các công nghệ liên quan cho các khách hàng đến từ Nhật Bản.', 'Phân tích thiết kế và lập trình chức năng của các website.', 'Chấp nhận sinh viên mới tốt nghiệp.', 'Tốt nghiệp đại học chuyên ngành IT\xa0', 'Thao tác tốt với HTML, CSS, JavaScript (Jquery, Ajax), Bootstrap, JSON, XML là lợi thế. \xa0\xa0', 'Có ít nhất 1 năm kinh nghiệm làm việc với Strust, Spring, Hibernate, VueJS \xa0\xa0', 'Có tư duy và giải thuật tốt \xa0\xa0', 'Có kinh nghiệm làm việc với AWS là một lợi thế \xa0\xa0', 'Hiểu biết về MVC Framework, ORM, RESTful, OOP, Design Pattern \xa0\xa0', 'Có kinh nghiệm làm việc với MySQL hoặc NoSQL (MongoDB) \xa0\xa0', 'Thành thạo các công cụ quản lý mã nguồn: GIT, SVN \xa0\xa0', 'Ưu tiên có kinh nghiệm làm việc với GWT, Java + Apache + struts2 + hibernate(HQL) \xa0\xa0', 'Viết code rõ ràng, dễ hiểu, dễ maintain, tuân thủ chặt chẽ convention\xa0', 'Tương tác với nhiều resources, nhiều dạng database là lợi thế. \xa0', 'Viết SQL tối ưu, không bị SQL Injection là lợi thế\xa0', 'Thiết kế database phù hợp yêu cầu, tối ưu cho performance', 'Mức lương khởi điểm hấp dẫn, cạnh tranh, tương xứng với năng lực và kinh nghiệm làm việc;\xa0', 'Thu nhập: 13 tháng lương/năm + thưởng dự án, thưởng Tết và các dịp lễ…;\xa0', 'Xét tăng lương 2 lần/năm theo năng lực và hiệu quả công việc;\xa0', 'Lương làm thêm giờ theo luật lao động, hỗ trợ đồ ăn OT theo quy định công ty;\xa0', 'Làm việc từ thứ 2 - thứ 6 (8h30 - 17h30);\xa0', 'Được tham gia BHXH, BHYT, BHTN theo quy định của pháp luật hiện hành;\xa0', 'Bảo hiểm chăm sóc sức khỏe 24/24 (Bảo Việt);\xa0', 'Khám sức khỏe định kỳ 1 năm/1 lần tại bệnh viện Đại học Y Hà Nội;\xa0', 'Nghỉ ốm hưởng nguyên lương tối đa 30 ngày/ năm (có giấy chứng nhận của bệnh viện);\xa0', 'Trợ cấp tiếng Nhật và các chứng chỉ IT liên quan (từ 1000.000 VNĐ - 2.500.000 VNĐ/tháng);\xa0', 'Phụ cấp thâm niên; phụ cấp chức vụ;\xa0', 'Được tham gia các câu lạc bộ của công ty: CLB Bóng đá, CLB Game, CLB Beauty, \xa0CLB Dance...\xa0', 'Được tham gia các hoạt động tập thể sôi động của công ty: nghỉ mát hàng năm, teambuilding hàng quý, gala cuối năm…', 'Tham gia các khóa học nâng cao trình độ chuyên môn qua Portal đào tạo nội bộ hoặc các khóa học trực tiếp với các giảng viên uy tín. \xa0', 'Cơ hội làm việc và đào tạo tại Nhật Bản với các ứng viên có tiếng Nhật\xa0', 'Làm việc trong môi trường chuyên nghiệp, được hỗ trợ phát huy khả năng, phát triển công việc tối đa.']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/backend-developer-php-python-java/896950.html?ta_source=JobSearchList>
#
# {'Title': 'Backend Developer', 'Company': 'CÔNG TY TNHH PETER & VIỆT NAM', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 20/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '2 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '2 năm', 'DiaChi': ['Hồ Chí Minh', 'Quận 1'], 'Skill': [], 'JobData': ['• Thảo luận về mục tiêu của dự án với khách hàng và nhóm phát triển.', '• Thiết kế và xây dựng các ứng dụng web bằng Laravel.', '• Khắc phục sự cố trong quá trình triển khai và gỡ lỗi bản dựng.', '• Làm việc với các nhà phát triển front-end và back-end trong các dự án.', '• Kiểm tra chức năng cho người dùng và chương trình phụ trợ.', '• Đảm bảo rằng các tích hợp chạy trơn tru.', '• Mở rộng dự án dựa trên phản hồi của khách hàng.', '• Ghi chép và báo cáo về công việc đã thực hiện trong Laravel.', '• Duy trì các ứng dụng dựa trên web.', '• Trình bày công việc trong các cuộc họp với khách hàng và quản lý.', '• Bằng cấp lập trình, khoa học máy tính hoặc một lĩnh vực liên quan.', '• Từ \xa002 năm kinh nghiệm làm việc với PHP, thực hiện kiểm thử đơn vị và quản lý các API như REST.', '• Hiểu biết vững chắc về thiết kế ứng dụng bằng Laravel.', '• Có kiến thức về thiết kế cơ sở dữ liệu và truy vấn bằng SQL.', '• Thành thạo HTML và JavaScript.', '• Trải nghiệm thực tế khi sử dụng kiến trúc MVC.', '• Danh mục các ứng dụng và chương trình mang tên bạn.', '• Kỹ năng giải quyết vấn đề và tư duy phản biện.', '• Kỹ năng giao tiếp tuyệt vời.', '• Mong muốn và khả năng học hỏi.', '• Tiếng Anh giao tiếp cơ bản', '• Bảo hiểm xã hội và y tế', '• Nghỉ thường niên', '• Ăn trưa và phụ cấp gửi xe', '• Đào tạo và nâng cao kỹ năng', '• Làm việc trong môi trường khởi nghiệp trẻ trung, năng động, thân thiện, khuyến khích phát triển bản thân, đãi ngộ theo quy định của công ty.']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/nhan-vien-it-tai-khach-san/896579.html?ta_source=JobSearchList>
#
# {'Title': 'Nhân Viên IT', 'Company': 'Công ty CPXD&PTHT Tây Hồ', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 30/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '1 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Nam', 'KinhNghiem': 'Không yêu cầu kinh nghiệm', 'DiaChi': ['Vĩnh Phúc', 'TP Vĩnh Yên'], 'Skill': [], 'JobData': ['Chịu trách nhiệm giám sát hoạt động phòng CNTT của khách sạn', 'Kịp thời xử lý những sự cố để đảm bảo hệ thống luôn hoạt động liên tục hiệu quả', 'Kiểm tra hoạt động hàng ngày của hệ thống hạ tầng CNTT của khách sạn : hệ thống mạng LAN, hệ thống wifi-internet, hệ thống khóa từ, ti vi, máy chủ ứng dụng, tổng đài nội bộ.', 'Trong quá trình kiểm tra hệ thống hạ tầng CNTT nếu phát hiện sự cố phải tiến hành xử lý ngay để không làm ảnh hưởng đến hoạt động của khách sạn', 'Thực hiện việc hướng dẫn, hỗ trợ vận hành hệ thống phần mềm nghiệp vụ cho nhân viên các bộ phận trong khách sạn : SMILE FO, POS, HR, BO, Purchasing,…', 'Tiếp nhận thông tin phản hồi về sự cố của các phần mềm từ nhân viên các bộ phận và tiến hành xử lý nhanh chóng', 'Thực hiện việc điều phối và hỗ trợ khách hàng xử lý các vấn đề về công nghệ thông tin', 'Chủ động tìm kiếm những ý tưởng cải tiến hoạt động của hệ thống phần mềm khách sạn', 'Làm các báo cáo công việc định kỳ hay có chỉ thị của cấp trên', 'Thực hiện các công việc khác khi được cấp trên giao phó.', ': Cao đẳng hoặc tương đương', ' Công nghệ thông tin hoặc ngành tương đương\xa0', ': Không yêu cầu', 'Tối thiểu 01 năm kinh nghiệm', ': Nắm vững kiến thức về công nghệ thông tin', 'Nắm được quy trình hoạt động của các phần mềm của Khách sạn.', ': Thành thạo trong việc cài đặt, vận hành hệ thống phần mềm Khách sạn.', 'Kỹ năng giao tiếp, truyền đạt thông tin.', 'Khả năng làm việc độc lập và làm việc nhóm.', 'Mức lương tương xứng năng lực', 'Môi trường dịch vụ chuyên nghiệp, năng động, thân thiện, không chất độc hại\xa0', 'Chế độ BHXH đầy đủ theo quy định\xa0', 'Hỗ trợ ăn ca ngoài lương', 'Thưởng các dịp lễ, tết\xa0', 'Chế độ xét lương hàng năm\xa0', 'Hỗ trợ 1 bữa ăn/ ca làm việc, có chỗ ở cho nhân viên ở xa\xa0', 'Công đoàn, sinh nhật hàng tháng...']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/net-developer/896817.html?ta_source=JobSearchList>
#
# {'Title': 'Developer', 'Company': 'Công ty Cổ phần Công nghệ Vinova', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 20/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '5 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '2 năm', 'DiaChi': ['Hà Nội', 'Đống Đa', 'Đà Nẵng', 'Sơn Trà', 'Hồ Chí Minh', 'Gò Vấp'], 'Skill': ['.NET', 'English'], 'JobData': ['Participate in requirements analysis', 'Collaborate with internal teams to produce software design and architecture', 'Write clean, scalable code using .NET programming languages', 'Test and deploy applications and systems', 'Revise, update, refactor and debug code', 'Improve existing software', 'Develop documentation throughout the software development life cycle (SDLC)', 'Serve as an expert on applications and provide technical support', 'At least 1 year of experience in ASP.NET Developer', 'Familiarity with the ASP.NET framework, SQL Server, MySQL and design/architectural patterns (e.g. Model-View-Controller (MVC))', 'Knowledge of at least one of the .NET languages (e.g, ASP .NET) and HTML5/CSS3', 'Experienced with .NET core', 'Familiarity with architecture styles/APIs (REST, RPC)', 'Familiarity with development tools: Git/SVN, Redmine, Visual Studio, Eclipse, NetBeans, Vagrant, etc.', 'Aggressive problem diagnosis and creative problem-solving skills.', 'Intermediate English skills.', 'BSc/BA in Computer Science, Engineering or a related field', 'Nice and friendly working environment.', 'Competitive salary with multiple bonus scheme', 'Lots of interesting and challenging projects to work on.', '13th-month salary benefits', 'Chance to work onsite abroad', 'We have a fun, Silicon Valley-style startup culture that values openness, fun, and awesomeness.', 'Attractive salary and annual salary review.', 'Provide devices for work.', 'Chance to become the leader of startup culture.', 'A fun, awesome work environment with multiple exciting bonus scheme', 'Progressive and international working environment.', 'Exciting company activities.', 'Free in-house entertainment facilities (football), coffee, and snack (instant noodles, cookies, candies…)']}
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/brand/coccoc/tuyen-dung/nhan-vien-danh-gia-tim-kiem-assessor-j878563.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/fresher-junior-backend-developer-net-java/897028.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.topcv.vn/brand/coccoc/tuyen-dung/nhan-vien-danh-gia-tim-kiem-assessor-j878563.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# Traceback (most recent call last):
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\defer.py", line 132, in iter_errback
#     yield next(it)
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 354, in __next__
#     return next(self.data)
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 354, in __next__
#     return next(self.data)
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "c:\Users\KHUONG\OneDrive\Documents\GitHub\LT_LT4KHDL\LTKHDL\collect_data\collect_data\spiders\colect_data.py", line 39, in parse_info
#     'DeadlineHoSo': response.css('div.job-deadline::text').getall()[1],
# IndexError: list index out of range
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/fresher-junior-backend-developer-net-java/897028.html?ta_source=JobSearchList>
#
# {'Title': 'Backend Developer', 'Company': 'Splus Software', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '2 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '1 năm', 'DiaChi': ['Hồ Chí Minh', 'Tân Bình'], 'Skill': [], 'JobData': ['Developing projects for Japanese and domestic customers.', 'Build a ticketing system, and optimize data', 'Read and understand detailed design, edit system functions existing systems, and develop new functions', 'The system that works with the WinForms app is vb.net and java web', 'Bachelor’s degree in Computer Science Engineering or other related courses.', 'At least 6 Month of experience working with dotNET (Winforms app), Java Web', 'Experience working with Postgresql databases, ability to write complex queries and optimize them', 'Proficiency with code versioning tools including Git, Github, SVN', 'Strong knowledge of front-end technologies including HTML5, JavaScript, and CSS3', 'Good problem-solving skills', 'Willing to work hard and learn new technologies', 'Having Japanese (equivalent to N3) or English is advanced', 'Working in a dynamic and professional environment with many opportunities for advancement.', 'The company provides equipment such as LAPTOP, Phones to serve the working needs of all employees.', 'The company pays all costs of social insurance, health insurance, and unemployment insurance for employees.', 'Join Health and Accident Insurance package 24/7 (according to seniority). Enjoy benefits according to seniority.', 'Being trained in foreign languages, and sponsored to study certificates to improve professional skills and soft skills.', 'Opportunity to go Onsite at SPLUS JAPAN (requires Japanese level of N3 or higher)', 'Performance evaluation: 2 times/year', 'Clubs: Football, Music, …', 'Annual company trip, quarterly teambuilding, employee birthdays in the month, and special events of the year (8/3, 20/10, Mid-Autumn Festival, Christmas...)', 'Annual leave: 12 vacation days, 11 holidays a year.']}
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/tester-uu-tien-biet-tieng-nhat-kiem-thu-phan-mem-upto-25m/623445.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/senior-android-developer/858913.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/ky-su-he-thong-system-engineer/874199.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/chuyen-vien-quan-tri-co-so-du-lieu-database-administrator/897100.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/lap-trinh-vien-php-thu-nhap-tu-14-20-trieu-thang/882037.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/lap-trinh-vien-web-frontend/880540.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/tester-uu-tien-biet-tieng-nhat-kiem-thu-phan-mem-upto-25m/623445.html?ta_source=JobSearchList>
#
# {'Title': 'Tester', 'Company': 'Công ty TNHH City Ascom Việt Nam', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/03/2023\n', 'Salary': '\nTới 20 triệu\n', 'Quantity': '5 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': 'Dưới 1 năm', 'DiaChi': ['Hà Nội', 'Đống Đa'], 'Skill': ['test cases', 'QC/QA', 'Automation Test', 'JLPT N3'], 'JobData': ['Nghiên cứu yêu cầu và thiết kế của sản phẩm / dự án', 'Xây dựng kế hoạch và kịch bản kiểm thử, chuẩn bị dữ liệu test', 'Test các sản phẩm hoặc dự án phần mềm, phối hợp với các team và phòng ban khác đảm bảo chất lượng của sản phẩm / dự án', 'Nắm bắt và hỗ trợ công việc kiểm soát đánh giá thực hiện quy trình phát triển phần mềm, đánh giá chất lượng sản phẩm trước khi triển khai chính thức', 'Thực hiện các công việc khác theo phân công của quản lý trực tiếp', 'Thưởng tối đa 3 lần/năm.\xa0', 'Xét tăng lương 2 lần/năm theo năng lực và hiệu quả công việc.', 'Trợ cấp ngoại ngữ hàng tháng (tiếng Nhật từ N4 trở lên, tiếng Anh Toeic từ 600 điểm trở lên).', 'Trợ cấp gia đình (vợ/chồng/con) hàng tháng.', 'Trợ cấp chức vụ hàng tháng từ Team leader trở lên.', 'Thưởng thành tích kinh doanh 1 năm/1 lần tùy tình hình kinh doanh của công ty.', 'Tham gia bảo hiểm xã hội trên 100% lương Gross. Đảm bảo về già bạn có lương hưu cao.', 'Khám sức khỏe định kỳ 1 năm/1 lần.', 'Ngày phép: 12 ngày/năm. ', 'Chế độ du lịch hàng năm và tham gia các hoạt động teambuilding, party liên hoan Công ty thường xuyên.', 'Nếu bạn chưa có kinh nghiệm, chúng tôi sẵn sàng đào tạo.', 'Được tiếp xúc nhiều công nghệ phong phú giúp bạn trưởng thành nhanh trong môi trường chuyên nghiệp.', 'Văn phòng đẹp như mơ, được đặt tại khu vực tiện lợi, có hầm đỗ xe, phòng ăn trưa, nghỉ trưa.', 'Đặc biệt có chương trình Giao Lưu Việt Nhật, hàng năm có nhân viên VN sang công ty mẹ ở Nhật làm việc và ngược lại.']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/senior-android-developer/858913.html?ta_source=JobSearchList>
#
# {'Title': 'Android Developer', 'Company': 'FPT Software', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 30/04/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '5 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '3 năm', 'DiaChi': ['Hà Nội', 'Cầu Giấy', 'Thạch Thất'], 'Skill': [], 'JobData': ['• Working in Global delivery team (US, China, India, Sing, VN,..)', '• Develop application/service for mobile (handheld) products in logistics industries, printing, scanning and so on…', '• Porting system to new chipset, upgrade Android OS version', '• Independently responsible for collecting, analyzing and handling customer requirements', '• Ensure the performance, quality, and responsiveness of applications', '• Integration / Backporting of CVEs mentioned in Google’s Monthly security bulletin', '• Source code conflict resolution if any patches cannot be applied directly.', '• Conduct Google compliance testing with latest version of test suites (CTS, CTS-Verifier, CTS-on-GSI, GTS, STS, VTS)', '• Fixing of defects arising due to Security Patches integration', '• Create analysis report & test report.', '• Bachelor’s degree in Computer Engineering, Electrical Engineering or Computer Science', '• At least 3 years’ experience in Android platform development & Linux Kernel Development', '• Proficiency in OOP, knowledge of data structures and algorithms.', '• Strong knowledge of Android framework development', '• Excellent C/C++, Java, JNI (Java native interface)', '• Experience with Linux kernel,', '• Strong knowledge in algorithm, data structure and object oriented programming', '• Familiar with Android/Linux build system', '• Proficiency with source control management such as Git, Repo, Gerrit or equivalent', '• Good English communication', '\xa0', '• Have experience in Google CVE and chipset CVE issue analysis and backporting', '• Have experience with Google compliance test program', '• Have experience with Qualcomm chipset.', '• Good knowledge of SELinux', '• Familiarity with Agile development processes', '• “FPT care” health insurance provided by AON and is exclusive for FPT employees.', '• Annual Summer Vacation: follows company’s policy and starts from May every year', '• Salary review 2 times/year or on excellent performance', '• International, dynamic, friendly working environment', '• Annual leave, working conditions follow Vietnam labor laws.', '• Other allowances: lunch allowance, working on-site allowance, etc.']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/ky-su-he-thong-system-engineer/874199.html?ta_source=JobSearchList>
#
# {'Title': 'System Engineer', 'Company': 'Công ty Cổ phần Viễn thông - Tin học Bưu điện', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 22/12/2022\n', 'Salary': '\nTới 1,800 USD\n ', 'Quantity': '2 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Nam', 'KinhNghiem': '1 năm', 'DiaChi': ['Hà Nội', 'Cầu Giấy'], 'Skill': ['System Admin', 'MCSA', 'VMWare'], 'JobData': ['Tham gia triển khai các dự án CNTT: khảo sát, lắp đặt, cấu hình, nghiệm thu, đào tạo', 'Cập nhật, nghiên cứu và làm chủ các giải pháp CNTT của các hãng Cisco, HPE, Dell/EMC, Nutanix,..', 'Triển khai, cấu hình tích hợp hệ thống và giải pháp của các hãng Cisco, HPE, DellEMC, Netapp,… cụ thể như sau:', '\xa0 \xa0 \xa0o Triển khai giải pháp Hyperconverged Infrastructure của hãng Cisco, DellEMC,…', '\xa0 \xa0 \xa0o Triển khai giải pháp Server, Storage, Backup của các hãng Cisco, DellEMC, HPE, Fujitsu,…', '\xa0 \xa0 \xa0o Cài đặt cấu hình hệ điều hành, cơ sở dữ liệu, Active Directory, DNS, Exchange', '1. Yêu cầu chung:', '- Tốt nghiệp ĐH chuyên ngành CNTT hoặc Điện tử Viễn thông', '- Có khả năng giao tiếp/ đọc hiểu tài liệu kỹ thuật bằng tiếng anh', '- Có khả năng làm việc độc lập, khả năng làm việc theo nhóm', '- Có khả năng làm việc trong môi trường áp lực cao. Kỹ năng xử lý tình huống tốt', '- Sử dụng thành thạo tin học văn phòng', '- Sẵn sàng làm ngoài giờ, đi công tác trong và ngoài nước khi cần thiết', '2. Yêu cầu riêng:', '- Có chứng chỉ MCSA, MCSE hoặc tương đương', '- Có chứng chỉ Vmware, LPIC, Netapp hoặc tương đương', '- Hiểu biết sâu các hệ thống máy chủ của Cisco, HPE, Dell, các hệ thống storage, SAN, Dell,…', '- Có kinh nghiệm cài đặt, quản trị và vận hành các hệ thống máy chủ, lưu trữ', '- Kinh nghiệm ở vị trí tương tự từ 1-2 năm', '- Gói thu nhập năm hấp dẫn, lên đến 1800$/ tháng', '- Thưởng lễ tết, tiền quần áo, ăn trưa, đi lại', '- Được hưởng đầy đủ các chế độ về BHXH, BHYT, BHTN theo quy định của Nhà nước', '- Công ty tài trợ nhiều khóa đào tạo, thi chứng chỉ của các hãng quốc tế']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/chuyen-vien-quan-tri-co-so-du-lieu-database-administrator/897100.html?ta_source=JobSearchList>
#
# {'Title': '\nChuyên Viên Quản Trị Cơ Sở Dữ Liệu (Database Administrator)\n', 'Company': 'Ngân Hàng Thương Mại Cổ Phần Kiên Long', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/01/2023\n', 'Salary': '\n15-30 triệu\n', 'Quantity': '1 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Nam', 'KinhNghiem': '3 năm', 'DiaChi': ['Hà Nội', 'Nam Từ Liêm'], 'Skill': ['Linux', 'Oracle', 'SQL', 'Unix'], 'JobData': ['Hệ thống cơ sở dữ liệu Oracle', 'Hệ thống Oracle Middleware.', 'Hệ điều hành Windows, Linux, Unix, Sun', 'Hệ thống ảo hóa.', 'Sử dụng các công cụ PL/SQL', 'Kiến thức tổng quát về hệ thống và hạ tầng CNTT.', 'Quản trị hệ thống cơ sở dữ liệu Oracle.', 'Quản trị hệ thống Middleware.', 'Vận hành các hệ điều hành Windows, Linux, Unix, Sun', 'Vận hành hệ thống ảo hóa.', 'Sử dụng các công cụ PL/SQL', 'Tối thiểu 2 năm kinh quản trị và vận hành các hệ thống liên quan.']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/lap-trinh-vien-php-thu-nhap-tu-14-20-trieu-thang/882037.html?ta_source=JobSearchList>
#
# {'Title': 'Lập Trình Viên PHP', 'Company': 'Công ty TNHH công nghệ Magezon', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 29/12/2022\n', 'Salary': '\n14-20 triệu\n', 'Quantity': '2 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': 'Dưới 1 năm', 'DiaChi': ['Nam Từ Liêm', 'Hà Nội'], 'Skill': [], 'JobData': ['- Lập trình PHP & Mysql trên nền Zend Framework\n', '- Tham gia phân tích, thiết kế, phát triển extension cho Magento 2\n', '- Tham gia vào các dự án phát triển website thương mại điện tử cho khách hàng trên toàn cầu\n', '- Tùy biến sản phẩm theo yêu cầu của khách hàng\n', '- Tham gia hỗ trợ khách hàng khi sử dụng sản phẩm\n', '- Làm việc nhóm với những lập trình viên PHP khác\n', '- Tối ưu sản phẩm, ứng dụng, website của khách hàng và công ty.\n', '- Tham gia quản lý nhóm nếu có khả năng phù hợp.', '- Trên 6 tháng kinh nghiệm làm việc với PHP.\n', '- Có kiến thức tốt về PHP, lập trình hướng đối tượng, mô hình MVC.\n', '- Có kiến thức tốt về HTML, CSS, Javascript, jQuery.\n', '- Đọc, hiểu, viết tiếng Anh chuyên ngành tốt. Sử dụng thành thạo Tiếng Anh là một lợi thế.\n', '- Có tinh thần học hỏi cao, năng động, sáng tạo và nhiệt tình trong công việc.\n', '- Có trách nhiệm cao với công việc.\n', '- Có tư duy logic tốt, có kỹ năng giải quyết vấn đề và làm việc trong môi trường áp lực.\n', '- Ưu tiên ứng viên đã có kinh nghiệm với những thư viện, mã nguồn mở như Laravel, Magento, Wordpress, Opencart, Prestashop,...', '- Thu nhập 14 - 20 tr/tháng\n', '- Lương hấp dẫn, theo thoả thuận, xứng đáng với hiệu quả công việc.\n', '- Xét tăng lương 1 năm/lần.\n', '- Lương tháng thứ 13.\n', '- Thưởng theo dự án, doanh thu, thưởng Tết và thưởng các ngày lễ.\n', '- Đầy đủ các chế độ, quyền lợi như BHXH, BHYT.\n', '- Được làm việc trong môi trường những người trẻ năng động, sáng tạo, ham học hỏi, chia sẻ và hỗ trợ bạn phát huy tối đa khả năng của mình.\n', '- Được tham gia các khóa đào tạo và phát triển cá nhân cả về chuyên môn, kỹ năng tiếng Anh và các kỹ năng mềm.\n', '- Làm việc 5 buổi / tuần, nghỉ thứ bảy, chủ nhật và nghỉ tất cả các ngày lễ theo quy định của Nhà nước.\n', '- Nghỉ phép tháng/năm theo luật lao động quy định.\n', '- Hỗ trợ ăn trưa, gửi xe.\n', '- Hỗ trợ máy tính và các trang thiết bị khác phục vụ công việc.']}
# 2022-12-21 17:13:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/lap-trinh-vien-web-frontend/880540.html?ta_source=JobSearchList>
#
# {'Title': 'Lập Trình Viên', 'Company': 'Công ty Dịch vụ MobiFone Khu vực 6 – CN Tổng Công ty Viễn thông MobiFone', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 28/12/2022\n', 'Salary': '\nTrên 10 triệu\n', 'Quantity': '3 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '1 năm', 'DiaChi': ['Nghệ An', 'TP Vinh'], 'Skill': ['AngularJS', 'HTML', 'Javascript', 'ReactJS'], 'JobData': ['\uf0fc Tham gia phát triển các dự án về Web, xây dựng các chức năng front-end của Website, Web application', '\uf0fc Triển khai giao diện HTML/CSS/Javascript theo yêu cầu trên hệ thống website xây dựng sẵn', '\uf0fc Thu thập ý kiến phản hồi và xây dựng các hướng giải quyết cho người sử dụng và khách hàng', '\uf0fc Nghiên cứu và áp dụng các phương pháp hoặc công nghệ thích hợp để giải quyết vấn đề', '\uf0fc Kỹ sư CNTT/ĐTVT, hệ chính quy, dưới 35 tuổi', '\uf0fc Có chứng chỉ B/Toeic 450 trở lên hoặc tương đương.', '\uf0fc Thành thạo ngôn ngữ lập trình Javascript/Typescript…', '\uf0fc Có kinh nghiệm sử dụng AngularJS/ReactJS/Vuejs…', '\uf0fc Kiến thức về lập trình và thiết kế hướng đối tượng (OOP)', '\uf0fc Kiến thức về cấu trúc dữ liệu & giải thuật, design patterns', '\uf0fc Kiến thức về quy trình phát triển phần mềm', '\uf0fc Tư duy tốt, có khả năng nghiên cứu, đánh giá và cập nhật công nghệ mới', '- Mức lương hấp dẫn, lương cứng tối thiểu từ 10-15 triệu đồng/tháng. Tổng thu nhập lên đến 400 triệu đồng/năm.', '- Thưởng các ngày Lễ, Tết, xét tăng lương hàng năm và lương theo vị trí công việc và thưởng theo doanh thu.', '- Bảo hiểm theo Quy định của nhà nước + Bảo hiểm sức khỏe của các đối tác hàng đầu như Bảo việt, PVI, Bảo Minh... khi khám chữa bệnh.', '- Phúc lợi: nghỉ mát, nghỉ phép, du xuân, khám sức khỏe hàng năm, trợ cấp ốm đau, hiếu, hỉ…', '- Được tham gia các khóa đào tạo trong và ngoài nước để nâng cao trình độ chuyên môn, nghiệp vụ.', '- Hỗ trợ chi phí học và thi các chứng chỉ quốc tế.', '- Được hưởng các chế độ ưu đãi khi sử dụng các dịch vụ của MobiFone.', '- Làm việc từ thứ 2-6, nghỉ thứ 7,CN.']}
# 2022-12-21 17:13:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/nhan-vien-lap-trinh-java/769895.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/nhan-vien-lap-trinh-java/769895.html?ta_source=JobSearchList>
#
# {'Title': 'Java', 'Company': 'Công ty TNHH đầu tư công nghệ và dịch vụ Sconnect Việt Nam', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 20/01/2023\n', 'Salary': '\n10-20 triệu\n ', 'Quantity': '3 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': 'Dưới 1 năm', 'DiaChi': ['Hà Nội', 'Thanh Xuân'], 'Skill': ['MySQL', 'Oracle', 'SQL Server', 'CSS3', 'Spring'], 'JobData': ['\xa0 + Nhân viên- Chuyên viên-Chuyên viên cao cấp- Chuyên gia – Chuyên gia cao cấp', '\xa0 + Nhân viên- Chuyên viên- Trưởng nhóm- Trưởng bộ phận- Giám đốc chuyên môn']}
# 2022-12-21 17:13:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/nhan-vien-it-support/841363.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/nhan-vien-it-support/841363.html?ta_source=JobSearchList>
#
# {'Title': 'Nhân Viên IT', 'Company': 'Công Ty TNHH Kiểm Toán & Tư Vấn RSM Việt Nam', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 20/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '1 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Nam', 'KinhNghiem': 'Không yêu cầu kinh nghiệm', 'DiaChi': ['Hồ Chí Minh', 'Quận 1'], 'Skill': [], 'JobData': ['Tiếp nhận và xử lý các yêu cầu của người dùng các lỗi \xa0máy tính, mạng, phần mềm & các thiết bị ngoại vi.', 'Bảo quản thiết bị CNTT: lắp đặt/thu hồi/điều chuyển thiết bị cho nhân viên và kiểm kê tài sản.', 'Sử dụng và vận hành hệ thống trong vai trò uỷ quyền administrator: MS 365, DC,Mail, GPO, Wifi, tổng đài IP Phone, tổng đài quản lý ra vào văn phòng', 'Đồng quản lý kiểm soát các trạng thái thiết bị trung tâm', 'Đã tham gia các khoá học tương đương PC/Laptop Pan, MCSA, CCNA, ảo hoá', 'Có kiến thức về bảo mật dành cho người dùng cuối', 'Không cần kinh nghiệm, ưu tiên ứng viên mới ra trường/ tốt nghiệp đại học.', 'Tham gia bảo hiểm xã hội theo quy định nhà nước', 'Số lượng ngày phép năm cạnh tranh', 'Cung cấp laptop, văn phòng phẩm làm việc', 'Cơ hội học tập và phát triển kỹ năng', 'Thời gian làm việc: Thứ 2 - Thứ 6']}
# 2022-12-21 17:13:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/nhan-vien-game-tester/636954.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/nhan-vien-game-tester/636954.html?ta_source=JobSearchList>
#
# {'Title': 'Tester', 'Company': 'Công ty TNHH đầu tư công nghệ và dịch vụ Sconnect Việt Nam', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 20/01/2023\n', 'Salary': '\n10-15 triệu\n', 'Quantity': '1 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': 'Dưới 1 năm', 'DiaChi': ['Hà Nội', 'Thanh Xuân'], 'Skill': ['Tester', 'test cases', 'test plan'], 'JobData': ['+ Nhân viên – Chuyên viên – Chuyên viên cao cấp – Chuyên gia – Chuyên gia cao cấp.', '+ Nhân viên – Chuyên viên – Trưởng nhóm – Trưởng bộ phận – Giám đốc chuyên môn.']}
# 2022-12-21 17:13:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/lap-trinh-vien-serverside-backend/880516.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:13:15 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/lap-trinh-vien-serverside-backend/880516.html?ta_source=JobSearchList>
#
# ...
# 2022-12-21 17:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/thuc-tap-sinh-lap-trinh-vien-dotnet-csharp-asp-net-sql-server/891763.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:14:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/net-developer-hcm-yeu-cau-1-nam-kinh-nghiem/888024.html?ta_source=JobSearchList>
#
# {'Title': 'Developer', 'Company': 'Công ty Cổ phần viễn thông FPT', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 31/01/2023\n', 'Salary': '\nThoả thuận\n', 'Quantity': '5 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': '1 năm', 'DiaChi': ['Hồ Chí Minh', 'Quận 7'], 'Skill': ['.NET', 'ASP.NET'], 'JobData': ['Tham gia đội ngũ phát triển Dự án Healthcare/ Dự án chuyển đổi số trên nền tảng web với vai trò Backend/ Fullstack.', 'Tham gia dự án chuyển đổi nền tảng ứng dụng, phát triển giải pháp back-end theo mô hình microservice.', 'Tham gia phát triển hệ thống Core-service với các nghiệp vụ về healthcare, hệ thống thông tin, chuyển đổi số.', 'Thực hiện code chính mảng Backend (.Net).', 'Các công việc khác theo phân công của techlead.', 'Tốt nghiệp Đại Học hoặc Cao Đẳng trở lên các chuyên nghành Công nghệ thông tin, hệ thống thông tin, Khoa học máy tính hoặc ngành liên quan.', 'Kinh nghiệm từ 1 năm trở lên, thành thạo .Net, C, MVC, .Net Core.', 'Am hiểu lập trình hướng đối tượng (OOP) và áp dụng design pattern.', 'Am hiểu việc gọi và xử lý RESTFul API.', 'Am hiểu và có kinh nghiệm làm việc với database: SQL server, Oracle, MySQL.', 'Có kiến thức về Design Software for Architects.', 'Có khả năng học hỏi nghiên cứu công nghệ mới.', 'Ưu tiên các ứng viên fullstack, biết thiết kế kiến trúc hệ thống, có chứng chỉ quốc tế.', 'Ưu tiên các ứng viên năng nổ hoạt động phong trào, thể dục thể thao.', 'Gói thu nhập năm tương đương từ 14 - 22 tháng lương quy đổi (Thưởng lương tháng 13, lương kinh doanh, tiền mừng tuổi...).', 'Đầy đủ các chế độ theo luật lao động hiện hành.', 'Chính sách phúc lợi theo quy định của Công ty đa dạng: Chăm sóc sức khỏe định kì hàng năm; Gói bảo hiểm sức khỏe chuyên biệt (FPT Care – Khám chữa bệnh miễn phí tại tất cả các bệnh viện); Các hoạt động tri ân, chăm lo đời sống tinh thần CBNV và Thân nhân....', 'Môi trường làm việc thân thiện, cởi mở.', 'Dự án Product, Đội ngũ chuyên gia hàng đầu, lộ trình thăng tiến rõ ràng.', 'Cơ sở vật chất và công cụ làm việc hiện đại, tiện nghi.', 'Nhiều cơ hội phát triển và thăng tiến.', 'Văn hóa Doanh nghiệp đặc sắc, sinh động bậc nhất với nhiều các hoạt động hấp dẫn: tân binh, 72 giờ trải nghiệm, teambuilding, thi trạng, hội làng, hội diễn Sao Chổi, sinh nhật FPT, ngày 08/03, ngày 11/11,...', 'Hưởng các gói ưu đãi cước khi sử dụng dịch vụ của FPT Telecom.']}
# 2022-12-21 17:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/brand/viettel1/tuyen-dung/chuyen-vien-quan-tri-ung-dung-thu-nhap-15m-25m-di-lam-ngay-j798568.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:14:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/thuc-tap-sinh-lap-trinh-vien-dotnet-csharp-asp-net-sql-server/891763.html?ta_source=JobSearchList>
#
# {'Title': 'Asp.Net', 'Company': 'CÔNG TY TNHH W2SOLUTION VIỆT NAM', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 12/01/2023\n', 'Salary': '\n Thoả thuận\n', 'Quantity': '10 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Thực tập sinh', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': 'Không yêu cầu kinh nghiệm', 'DiaChi': ['Hồ Chí Minh', 'Quận 3'], 'Skill': ['ASP.NET', 'C#', 'SQL Server', 'ASP.NET MVC'], 'JobData': ['- Tham gia phát triển các dự án phần mềm', '- Tham gia thực tập Full-time', '- Tìm hiểu và phát triển chức năng Web E-Commerce', '- Được hướng dẫn về ý thức chất lượng, teamwork', '- Một số công việc khác sẽ trao đổi cụ thể trong buổi phỏng vấn', '- Có kỹ năng và hiểu biết về : \xa0Csharp, \xa0ASP.NET, SQL Server', '- Đã tốt nghiệp Cao đẳng / Đại Học hoặc đang đợi Bằng (ngành Công nghệ thông tin, Phần mềm)', '- Cung cấp bảng điểm tại trường đang theo học (Trường hợp chưa có Bằng)', '- Có hiểu biết về E-Commerce là một lợi thế', '- Hằng ngày được trợ cấp cơm trưa, học lớp tiếng Nhật miễn phí', '- Được tham gia các hoạt động Team Building như : thể thao, tiệc Công ty,...', '- Môi trường làm việc Nhật Bản thân thiện, năng động, chuyên nghiệp', '- Được đánh giá kết quả sau thời gian thực tập để trở thành nhân viên chính thức.', '\xa0 \xa0\xa0', '■ Khi trở thành nhân viên chính thức sẽ được thêm những phúc lợi sau :', '- Lương tháng 13', '- Khám sức khỏe định kỳ, du lịch công ty hằng năm', '- Tham gia đầy đủ chế độ Bảo hiểm xã hội, Bảo hiểm y tế,…', '- Lương, trợ cấp thỏa thuận theo năng lực làm việc', '- Đánh giá Performance 3 tháng 1 lần.']}
# 2022-12-21 17:14:13 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.topcv.vn/brand/viettel1/tuyen-dung/chuyen-vien-quan-tri-ung-dung-thu-nhap-15m-25m-di-lam-ngay-j798568.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# Traceback (most recent call last):
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\defer.py", line 132, in iter_errback
#     yield next(it)
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 354, in __next__
#     return next(self.data)
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 354, in __next__
#     return next(self.data)
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 342, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 40, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "C:\Users\KHUONG\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 66, in _evaluate_iterable
#     for r in iterable:
#   File "c:\Users\KHUONG\OneDrive\Documents\GitHub\LT_LT4KHDL\LTKHDL\collect_data\collect_data\spiders\colect_data.py", line 39, in parse_info
#     'DeadlineHoSo': response.css('div.job-deadline::text').getall()[1],
# IndexError: list index out of range
# 2022-12-21 17:14:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.topcv.vn/viec-lam/khai-thac-ung-dung-trien-khai-cac-giai-phap-cntt-co-the-di-lam-sau-tet-thu-nhap-len-den-480-trieu-nam/890098.html?ta_source=JobSearchList> (referer: https://www.topcv.vn/viec-lam-it?page=1)
# 2022-12-21 17:14:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.topcv.vn/viec-lam/khai-thac-ung-dung-trien-khai-cac-giai-phap-cntt-co-the-di-lam-sau-tet-thu-nhap-len-den-480-trieu-nam/890098.html?ta_source=JobSearchList>
#
# {'Title': '\nKhai Thác Ứng Dụng & Triển Khai Các Giải Pháp CNTT (Có Thể Đi Làm Sau Tết) - Thu Nhập Lên Đến 480 Triệu/Năm\n', 'Company': 'TRUNG TÂM CNTT MOBIFONE', 'DeadlineHoSo': ' Hạn nộp hồ sơ: 10/01/2023\n', 'Salary': '\nTới 40 triệu\n', 'Quantity': '14 người', 'Hthuc': 'Toàn thời gian', 'CapBac': 'Nhân viên', 'GioiTinh': 'Không yêu cầu', 'KinhNghiem': 'Dưới 1 năm', 'DiaChi': ['Cầu Giấy', 'Hoàng Mai', 'Hà Nội'], 'Skill': [], 'JobData': ['- Vận hành, khai thác, giám sát các hệ thống máy chủ ứng dụng và hoạt động của các ứng dụng hệ thống CNTT phục vụ SXKD và nội bộ của MobiFone.', '- Khai thác nghiệp vụ các hệ thống kinh doanh CNTT: Tổng đài Cloud Contact Center (3C), Truyền thông thông minh, AI Camera, Hóa đơn điện tử …', '- Nghiên cứu, phát triển các dịch vụ CNTT hợp tác, các giải pháp công nghệ mới.\n', '- Tư vấn, triển khai các sản phẩm CNTT tới khách hàng, xây dựng tài liệu, hồ sơ kỹ thuật, triển khai và bảo hành cho các dự án.', '- Trình bày, demo, đào tạo, giới thiệu, tư vấn sản phẩm cho khách hàng và các Công ty khu vực.', '1. Trung tâm Công nghệ thông tin MobiFone - MobiFone IT (tuyển dụng 03 nhân sự)', '2. Trung tâm Tính cước và Thanh khoản MobiFone (tuyển dụng 06 nhân sự)', '3. Trung tâm Mạng lưới MobiFone miền Bắc\xa0(tuyển dụng 02\xa0nhân sự)', '4. Trung tâm Dịch vụ Số MobiFone - MDS (tuyển dụng 03 chỉ tiêu)', '- \xa0Trình độ Đại học trở lên, hệ đào tạo chính quy, chuyên ngành CNTT/ĐTVT/Toán-Tin hoặc tương đương\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0', '- \xa0Độ tuổi: Dưới 35 tuổi\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\n', '- \xa0Ngoại ngữ: Tiếng Anh trình độ B trở lên hoặc tương đương\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\n', '-\xa0\xa0 Có hiểu biết sâu và rộng rãi về các sản phẩm và lĩnh vực CNTT bao gồm cả phần cứng và phần mềm.', '-\xa0\xa0 Am hiểu về kiến trúc hệ thống và sản phẩm phần mềm.\n', '-\xa0\xa0 Có hiểu biết về các công nghệ mới: AI, IOT, Blockchain…\n', '-\xa0\xa0 Có kinh nghiệm về xây dựng hồ sơ kỹ thuật cho các dự án.\n', '-\xa0\xa0 Ưu tiên ứng viên có kinh nghiệm tư vấn, hỗ trợ kỹ thuật, chăm sóc khách hàng cho các sản phẩm CNTT.', '-\xa0\xa0 Ưu tiên ứng viên có kinh nghiệm làm vận hành ứng dụng hệ thống CNTT.', '- Thời gian làm việc từ thứ 2 đến thứ 6 (nghỉ thứ 7, Chủ nhật)\n', '- Quyền lợi về Bảo hiểm xã hội/thất nghiệp và các phúc lợi hấp dẫn khác, gói bảo hiểm y tế quyền lợi đến $8000', '- Các chế độ bồi dưỡng, ăn trưa 1.000.000đ/tháng, thuê bao nội bộ 320.000đ/tháng\n', '- Được đào tạo phát triển bản thân, nâng cao các kỹ năng và chuyên môn nghề nghiệp\n', '- Làm việc tại môi trường chuyên nghiệp, năng động, trẻ trung và trải nghiệm các hoạt động văn hóa doanh nghiệp đặc sắc', '- Cơ hội tiếp cận với những doanh nghiệp, dự án lớn, những xu hướng công nghệ/nền tảng mới nhất, thỏa sức sáng tạo phát triển bản thân', '\n']}
# 2022-12-21 17:14:13 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-12-21 17:14:13 [scrapy.extensions.feedexport] INFO: Stored csv feed (410 items) in: dataset/info.csv
# 2022-12-21 17:14:13 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 485952,
#  'downloader/request_count': 460,
#  'downloader/request_method_count/GET': 460,
#  'downloader/response_bytes': 36430937,
#  'downloader/response_count': 460,
#  'downloader/response_status_count/200': 460,
#  'elapsed_time_seconds': 67.279539,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 12, 21, 10, 14, 13, 587706),
#  'httpcompression/response_bytes': 152915784,
#  'httpcompression/response_count': 460,
#  'item_scraped_count': 410,
#  'log_count/DEBUG': 875,
#  'log_count/ERROR': 41,
#  'log_count/INFO': 12,
#  'request_depth_max': 9,
#  'response_received_count': 460,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 459,
#  'scheduler/dequeued/memory': 459,
#  'scheduler/enqueued': 459,
#  'scheduler/enqueued/memory': 459,
#  'spider_exceptions/IndexError': 40,
#  'spider_exceptions/UnboundLocalError': 1,
#  'start_time': datetime.datetime(2022, 12, 21, 10, 13, 6, 308167)}
# 2022-12-21 17:14:13 [scrapy.core.engine] INFO: Spider closed (finished)
