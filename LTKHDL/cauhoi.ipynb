# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Câu hỏi: Nhu cầu việc làm của các lĩnh vực IT theo các khu vực có sự khác nhau hay không? Liệu có sự chênh lệch về lương của các khu vực này theo từng ngành nghề ?

# %% [markdown]
# Đọc file dữ liệu

# %%
df = pd.read_csv('data.csv',index_col='Unnamed: 0')
df.head(5)
# Out:
#                                                Title  \
# 0                                   Business Analyst
# 1                                  Android Developer
# 2                                       Nhân Viên IT
# 3  Chuyên Viên Quản Trị Cơ Sở Dữ Liệu (Database A...
# 4                                     Java Developer
#
#                                   Company DeadlineHoSo           Salary  \
# 0                         Asilla Việt Nam   2023-01-31     (1200, 1400)
# 1                            FPT Software   2023-04-30              NaN
# 2                Công ty CPXD&PTHT Tây Hồ   2023-01-30              NaN
# 3  Ngân Hàng Thương Mại Cổ Phần Kiên Long   2023-01-31  (600.0, 1200.0)
# 4            CÔNG TY TNHH YOUMED VIỆT NAM   2023-01-31              NaN
#
#    Quantity           Hthuc     CapBac       GioiTinh  KinhNghiem  \
# 0         5  Toàn thời gian  Nhân viên  Không yêu cầu         3.0
# 1         5  Toàn thời gian  Nhân viên  Không yêu cầu         3.0
# 2         1  Toàn thời gian  Nhân viên            Nam         0.0
# 3         1  Toàn thời gian  Nhân viên            Nam         3.0
# 4         3  Toàn thời gian  Nhân viên  Không yêu cầu         1.0
#
#                        DiaChi                                        Skill  \
# 0             Cầu Giấy,Hà Nội                                          NaN
# 1  Hà Nội,Cầu Giấy,Thạch Thất                                          NaN
# 2       Vĩnh Phúc,TP Vĩnh Yên                                          NaN
# 3          Hà Nội,Nam Từ Liêm                        Linux,Oracle,SQL,Unix
# 4         Hồ Chí Minh,Quận 10  Java,Message Queue,Back-End Web Development
#
#                                              JobData
# 0  - Collaborate with Product Manager to understa...
# 1  • Working in Global delivery team (US, China, ...
# 2  Chịu trách nhiệm giám sát hoạt động pho...
# 3  Hệ thống cơ sở dữ liệu Oracle,Hệ thống Oracle ...
# 4  Phát triển tính năng đặt khám, telemedicine, s...

# %% [markdown]
# Ta sẽ chuyển sang dataframe khác để không ảnh hưởng đến df chính

# %%
temp_df = df

# %% [markdown]
# Đầu tiên, ta sẽ phân loại các ngành nghề từ mục Title, các ngành nghề sẽ được phân loại thành các mục sau:
#
#
# - Design
#
# - Management
#
# - Product and Business
#
# - Security
#
# - Help Desk
#
# - Testing
#
# - Infrastructure
#
# - Data & Ai
#
# - Software
#
# - Khác

# %% [markdown]
# Chuyển mục title sang chữ thường để phân loại dễ hơn

# %%
temp_df['Title'] = temp_df['Title'].str.lower()

# %%
temp_df['Title'].unique()
# Out:
# array(['business analyst', 'android developer', 'nhân viên it',
#        'chuyên viên quản trị cơ sở dữ liệu (database administrator)',
#        'java developer', 'nhân sự', 'tester', 'backend developer',
#        'system engineer', 'lập trình viên', 'lập trình viên php',
#        'kỹ sư an ninh bảo mật (không yêu cầu kinh nghiệm)',
#        'php developer', 'magento developer', 'it support', 'developer',
#        'digital marketing', 'unity developer', 'fullstack developer',
#        'internship công nghệ thông tin', 'java', 'product manager',
#        'kĩ thuật viên lương từ 15tr', 'nhân viên quản trị mạng',
#        'qc engineer',
#        'chuyên viên an ninh thông tin (có thể đi làm sau tết) - thu nhập lên đến 480 triệu/năm',
#        'trưởng phòng it', 'python',
#        'khai thác ứng dụng & triển khai các giải pháp cntt (có thể đi làm sau tết) - thu nhập lên đến 480 triệu/năm',
#        'asp.net', 'nhân viên phát triển phần mềm',
#        'react native developer', 'ai engineer', 'android',
#        'product owner', 'angularjs', 'software engineer', 'reactjs',
#        'data analyst', 'product owner (lên tới 35 triệu vnđ)', 'nodejs',
#        'devops engineer', 'mobile developer',
#        'chuyên viên triển khai phần mềm [cầu giấy-hà nội] (8-12 triệu)',
#        'phân tích nghiệp vụ', 'ruby on rails',
#        'nhân viên trực hệ thống (noc) mobifone global (từ 6,3 triệu trở lên)',
#        'qa_manual testers tại technopark lương up to 20m',
#        'it system administrator ', 'facebook ads',
#        'chuyên viên xây dựng/viết quy trình vận hành (thu nhập tới 20 triệu/tháng - kinh nghiệm từ 2 năm)',
#        'data analysis', 'nhân viên lập trình .net', 'nhân viên marketing',
#        'ios developer', 'frontend developer',
#        'cán bộ phát triển hệ thống', 'it helpdesk', 'engineering manager',
#        'nhân viên backend', 'game designer', 'thực tập sinh',
#        'kỹ sư sfcs', 'software developer', 'game developer',
#        'recruitment of senior dev ops engineer (salary above 60 million vnd)',
#        'chuyên viên development backend thu nhập từ 10-40 triệu ở hà nội',
#        'project manager', 'system admin', 'account executive',
#        'nhân viên kỹ thuật', 'nhân viên triển khai phần mềm',
#        'kỹ thuật sửa máy tính (hồ chí minh)', 'vuejs',
#        'senior deverloper microsoft crm (dynamics)',
#        'chuyên viên phần mềm tại hà nội (thu nhập từ 10 - 25 triệu)',
#        'quản trị hệ thống',
#        'nhân viên quản trị và phát triển website - thương hiệu thời trang anta [thủ đức-tp.hcm]',
#        'full stack developer',
#        'fresher game admin (nhận uv chưa có kinh nghiệm)',
#        'giảng viên quản trị mạng', 'it security',
#        'qc engineer (junior/senior)', 'chăm sóc khách hàng',
#        'chuyên viên lập trình phần mềm',
#        'test leader tại hà nội/thanh hoá ( lương từ 20-30 triệu)',
#        'front end developer', 'kỹ sư phần mềm', 'it customer support',
#        'javascript',
#        'nhân viên intern mobile dev - flutter (không yêu cầu kinh nghiệm )',
#        'cộng tác viên triển khai bản vẽ nhà gỗ nhật (fulltime tại văn phòng)',
#        'it network administrator (chưa có kinh nghiệm sẽ được đào tạo)',
#        'data engineer', 'chuyên viên an toàn bảo mật', 'devops',
#        'cloud engineer', 'trưởng nhóm it lương 35 triệu/tháng',
#        'react native', 'tích hợp hệ thống', 'lập trình phần mềm nhúng',
#        'laravel', 'chuyên viên kỹ thuật mạng', 'unity',
#        'nhân viên nhập liệu', 'it application support',
#        'nhân viên coder html tại hcm', 'ui designer',
#        'trưởng nhóm phát triển sản phẩm giải trí trực tuyến (product owner)',
#        'backend engineer', 'database administrator',
#        'kỹ sư phần mềm tại srilanka',
#        'chuyên viên cao cấp vận hành hệ thống online banking',
#        'chuyên viên an toàn thông tin - pentest', 'ui/ux designer',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ long điềm - biên hòa - đồng nai ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ trảng dài - biên hòa - đồng nai ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ tân phú - đồng nai ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ long bình tân - biên hòa - đồng nai ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ bắc bình - bình thuận ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ ngã ba tam biên - phan thiết - bình thuận ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ phan rí cửa - tuy phong - bình thuận ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ đức long - phan thiết - bình thuận ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ phú thủy - phan thiết - bình thuận ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ mũi né - phan thiết - bình thuận ]',
#        'nhân viên kiểm thử phần mềm', 'fresher mobile dev',
#        'product manager (upto $1500 + esop)', 'full stack .net engineer',
#        '2d game animator - upto $1,200', 'nhân viên content',
#        'web developer', 'solution architect', 'thực tập sinh it',
#        'nhân viên thiết kế', 'lập trình web', 'quản trị website',
#        'ux researcher', 'ios', 'lập trình viên java', 'angular',
#        'c/c++ application engineer (600$ - 2000$)', 'php',
#        'lập trình viên mobile', 'qa/qc',
#        'chuyên viên triển khai phần mềm', 'kỹ sư cầu nối',
#        'network engineer', 'lập trình viên react native',
#        'nhân viên phát triển thị trường', 'senior developer',
#        'nhân viên chăm sóc khách hàng', 'it help desk',
#        'nhân viên hỗ trợ vận hành ứng dụng công nghệ thông tin',
#        'backend dev (all level)', 'nhân viên kĩ thuật giải pháp',
#        'product owner - senior', 'giảng viên trí tuệ nhân tạo',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop khai trương shop mới [xã đại phước, h. nhơn trạch - đồng nai]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ hàm thuận nam - bình thuận ]',
#        'magento', 'product manager (ai camera)',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ vĩnh cửu - đồng nai ]',
#        'embedded engineer (autosar)',
#        'freelancer thiết kế giao diện web/app', 'it security enginer',
#        '.net developer', 'quản trị mạng',
#        'nhân viên lập trình và service desk ( lương hấp dẫn đến 25 triệu )',
#        'it customer support service', 'lập trình game', 'video editor',
#        'kĩ sư lập trình nhúng (13m - 40m)',
#        'database administrator (lương thưởng - chế độ hấp dẫn)', 'pqa',
#        'kỹ sư hiện trường hệ thống điện nhẹ và công nghệ thông tin',
#        'project coordinator', 'quản lý', 'nhân viên qa',
#        'delivery manager', 'senior embedded engineer (autosar)',
#        'xử lý dữ liệu', 'kỹ sư hệ thống', 'chuyên viên it',
#        'nhân viên hỗ trợ vận hành hệ thống cntt (ict helpdesk)',
#        'kỹ sư lập trình', 'senior iot engineer - upto 2500$',
#        'fresher/tts devops_không yêu cầu kinh nghiệm',
#        'account manager fresher', 'it project management assistant',
#        'thực tập sinh lập trình nhúng embedded c',
#        'kỹ sư tự động hóa it - lương 2000 usd (đi làm sau tết)',
#        'qc engineer (junior)', 'hành chính', 'frontend tech lead',
#        'data admin',
#        'fresher phát triển ứng dụng - lương 1200 usd (đi làm sau tết)',
#        'lập trình c#, .net (nha trang - khánh hòa)',
#        'trưởng nhóm kiểm thử (qc lead)',
#        'qc automation (intern/ fresher)', 'lập trình viên .net',
#        'kỹ sư networking', 'trợ lý', 'product marketing', '2d artist',
#        'nhân viên hỗ trợ it', 'giám đốc điều hành',
#        'chuyên viên điều phối dự án - project coordinator',
#        'nhân viên 2d artist - cầu giấy hà nội',
#        'it engineer (help desk/ support)',
#        'chuyên viên full-stack development',
#        'trưởng phòng it - làm việc tại đà nẵng', 'frontend engineer',
#        'nhân viên kiểm thử mobile app (up to $1500)',
#        'quản trị dự án (pm)', 'kỹ sư hệ thống cntt', 'server engineer',
#        'agile coach / scrum master - trung tâm công nghệ',
#        'service delivery manager - signing bonus up to 50m (onsite korea)',
#        'data scientist', 'server engineer internship',
#        'chuyên viên vận hành ứng dụng',
#        'database administrator (dba) - up to $2500',
#        'senior microsoft engineer', 'junior microsoft security engineer',
#        'senior cloud engineer', 'junior aws engineer',
#        'junior microsoft engineer', 'test leader',
#        'kỹ sư hệ thống tại hà nội',
#        'data governance - trung tâm công nghệ', 'quality assurance',
#        'game vfx', 'tiếng nhật',
#        'nhân viên dán nhãn dữ liệu (data labelling expert)', 'brse',
#        'senior test (dự án khối chính phủ) - hà nội',
#        'cán bộ triển khai công nghệ mạng bảo mật',
#        'quản trị dự án phần cứng', 'network administrator',
#        'helpdesk (japanese)_night shift',
#        'mobile leader - trung tâm công nghệ', 'it comtor',
#        'service delivery manager (n2) - signing bonus up to 50m',
#        'it system', 'kỹ sư frontend công ty calc (nhật bản)',
#        'it project (sharepoint project and helpdesk project) - fulltime remote',
#        'ngân hàng',
#        'chuyên viên triển khai, tích hợp hệ thống contact center',
#        'nhân viên lập trình tại hà nội', 'senior product owner',
#        'technical team lead',
#        'technical support leader (html, css, js) - night shift',
#        'nhân viên tích hợp hệ thống (vận hành hệ thống)',
#        'golang engineer', 'kỹ sư hệ thống - nghiên cứu networking',
#        'fraud analyst - chuyên gia phân tích gian lận',
#        'kỹ sư hệ thống - openstack', 'quản lý chất lượng', 'ux designer',
#        'product owner (upto 15 triệu)', 'tech lead',
#        'javascript developer', 'chuyên viên hỗ trợ kỹ thuật',
#        'embedded engineer (iot)', 'technical supporter',
#        'motion planning engineer',
#        'nhân viên hỗ trợ kỹ thuật sản phẩm apple [tổ 12 ngã ba phú mỹ - brvt ]',
#        'nhân viên vận hành hệ thống', 'fresher flutter',
#        'kỹ sư quản trị cơ sở dữ liệu',
#        'trưởng phòng giải pháp công nghệ thông tin, lương thỏa thuận',
#        'nhân viên r&d', 'nhân viên vi tính', 'account manager it',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ hàm tân - bình thuận ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [tt. đức tài, đức linh - bình thuận]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ liên hương - tuy phong - bình thuận ]',
#        'nhân viên hỗ trợ kỹ thuật đtdd/laptop khai trương shop mới [tt. ma lâm, hàm thuận bắc - bình thuận]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ la gi - bình thuận ]',
#        'nhân viên triển khai phần mềm ', 'web designer',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ túc trưng - định quán - đồng nai ]',
#        'kỹ sư vận hành hệ thống storage', 'lập trình viên javascript',
#        'tiếng anh', 'nhân viên hỗ trợ dự án', 'back end developer',
#        'project assistant', 'project team leader', 'technical support',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ ngã 3 phú mỹ - tx. phú mỹ - brvt ]',
#        'chuyên viên development backend thu nhập từ 6-30 triệu ở hà nội',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ mỹ xuân, tx. phú mỹ - brvt ]',
#        'kỹ sư công nghệ thông tin',
#        'senior c/c++ - signing bonus upto 3 months salary',
#        'it infrastructure engineer', 'chuyên viên lập trình',
#        'chuyên viên hệ thống thông tin', 'junior back-end',
#        'data collection engineer', 'kỹ sử bảo mật hệ thống thông tin',
#        'chuyên viên phát triển dữ liệu',
#        'system architecture tại hồ chí minh - up to $3000',
#        'nhân viên khai thác tài nguyên mạng', 'designer',
#        'nhân viên lập trình mobile app', 'lập trình ứng dụng',
#        'art director',
#        'cyber security analyst all level thị trường âu mỹ',
#        'back-end dev (.net, api, mysql) - sign on bonus', 'it backend',
#        'computer vision engineer (mid-senior)', 'game artist',
#        'content creator', 'mobile engineer', 'backend developers',
#        'team leader web (.net)', 'seo',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop khai trương shop mới [nguyễn hội, phan thiết - bình thuận]',
#        'back end engineer', 'kỹ thuật',
#        'intern frontend/ backend part time',
#        'kỹ sư quản trị cơ sở dữ liệu (database administrator)',
#        'nhân viên công nghệ thông tin/it phần cứng (it attendant)',
#        'kỹ sư phần mềm nhúng junior (up to 1200$)', 'ui/ux',
#        'kỹ sư phát triển phần mềm whmcs', 'game engineer',
#        'software solution /it application architect/technical lead',
#        'technical support executive',
#        'software development intern (frontend/backend)',
#        'nhân viên bảo mật (security engineer)',
#        'nhân viên lập trình abap',
#        'product development executive (software) - hcm', 'cae engineer',
#        'nhân viên video creative', 'test engineer',
#        'product development - phát triển sản phẩm (công nghệ thông tin, viễn thông) - onboard sau tết',
#        'chuyên viên mua hàng', 'nhân viên vận hành dịch vụ',
#        'technical leader', 'tổng giám đốc', 'laboratory electrician',
#        'senior technical support (lương up to 2000$)',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ đường 30/4 - tp. vũng tàu - brvt ]',
#        'pm/leader', 'fresher c/embedded tại quy nhơn',
#        'nhân viên phòng công nghệ thông tin', 'it staff', '.net engineer',
#        'thực tập sinh .net', 'thực tập sinh golang',
#        'thực tập sinh front - end', 'thực tập sinh infrastructure',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [phước hải, đất đỏ - brvt ]',
#        'lập trình php', 'middle qc engineer', 'front-end leader',
#        'open stack engineer', 'phiên dịch tiếng nhật', 'trưởng nhóm it',
#        'senior qc engineer (test, sql)',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ 155 nguyễn thái học - tp. vũng tàu - brvt ]',
#        'it analyst',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ xuyên mộc - bà rịa vũng tàu ]',
#        'nhân viên hỗ trợ kỹ thuật đtdd/laptop khai trương shop mới [xã bình châu, h. xuyên mộc - brvt]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ 258 ba cu - tp. vũng tàu - brvt ]',
#        'nhân viên lập trình', 'it engineer',
#        'senior data reporting specialist (pl/sql)',
#        'chuyên viên cao cấp thiết kế chiến lược - msb df - dxk - 1m348',
#        'erp manager', 'nhân viên quản trị web', 'game 2d',
#        'nhân viên mobile app',
#        'senior database engineer (mysql, rds, aws)',
#        'trưởng nhóm lập trình - thu nhập hấp dẫn', 'nhân viên back end',
#        'nhân viên triển khai phần mềm erp',
#        'team lead (trưởng nhóm kỹ thuật)',
#        'microwave transmission engineer', 'fresher c#', '.net internship',
#        'game programer', 'trưởng phòng quản trị dự án cntt',
#        'nhân viên hỗ trợ kỹ thuật đtdd/laptop [shop mới 618 cách mạng tháng tám, thủ dầu một - bình dương]',
#        'database admin system', 'chuyên viên kiểm thử phần mềm',
#        'talent acquisition specialist',
#        'chuyên viên cao cấp triển khai back-end - msb df - dxn - 1m344',
#        'chuyên viên cao cấp thiết kế giao diện và trải nghiệm người dùng - msb df - dxk - 1m342',
#        'kiểm thử phần mềm dự án blockchain', 'business intelligence (bi)',
#        'coordinator (nhận cv từ trainee)',
#        'it engineer - elite fitness hà nội',
#        'kiến trúc sư trưởng hệ thống cntt',
#        'l&d manager (trưởng phòng đào tạo)', 'talent acquisition',
#        'sap basis intern', 'sap abap intern',
#        'chuyên viên quản trị mạng và bảo mật',
#        'embedded linux engineer (c++)', 'backend development intern',
#        'senior qa engineer',
#        '\\nhân viên phát triển dịch vụ web (ứng dụng)',
#        'chuyên viên vận hành hệ thống (tp vinh)',
#        'kỹ thuật viên máy tính camera tại rạch giá kiên giang',
#        'quality control', 'senior it application specialist',
#        'cán bộ triển khai công nghệ hệ thống',
#        'nhân viên triển khai hệ thống cntt', 'fullstack engineer',
#        'head of d&a (data analytics)', 'business solution assistant',
#        'mid-senior product owner',
#        'database administrator (dba) - tp hcm',
#        'nhân viên kiểm thử (mobile app)', 'golang technical',
#        'web frontend intern full - time (có lương hỗ trợ)',
#        'scrum master',
#        'chuyên gia vận hành dịch vụ cloud - it bu - dxnb - msbit bu - dxk - 3i003',
#        'chuyên viên chính tích hợp dữ liệu (data) - msbit bu - dxk - 3i010',
#        'chuyên viên cao cấp kiểm thử - msb df - dxd - 3i009',
#        'chuyên viên cao cấp quản trị dự án và hiệu suất công việc - msbit bu - dxk - 3i013',
#        'kỹ sư mạng và an toàn thông tin (fresher)',
#        'trưởng nhóm/chuyên gia quản trị cơ sở dữ liệu (dba)',
#        'thiết kế đồ họa', 'cloud engineer thị trường âu mỹ',
#        'blockchain technical leader', 'trưởng nhóm triển khai phần mềm',
#        'qa manual engineer (blockchain/crypto/defi) (hn/hcm)',
#        'technical writer (blockchain/crypto/defi) - product team (singapore)',
#        'react js', 'giáo viên', 'game server', 'partnership manager',
#        'nhân viên seo', 'trưởng phòng ai',
#        'senior qa automation engineer',
#        'natural language processing (nlp) engineer - kỹ sư xử lý ngôn ngữ tự nhiên',
#        'senior smart contract engineer (blockchain/crypto/defi) (work from anywhere)',
#        'marketing leader', 'it executive', 'frontend mobile',
#        'node.js technical leader',
#        'kỹ sư quản trị cơ sở dữ liệu (dba oracle, sql)',
#        'giảng viên ccna', 'senior it operation',
#        '.net technical team leader', 'aws engineer salary up to 1300$',
#        'chuyên viên hoạch định tài chính - kênh pruventure [đà nẵng]',
#        'trưởng nhóm kiểm thử phần mềm (test lead)',
#        'l&d leader (learning & development - it company - upto 35m)',
#        'compliance associate', ' blockchain engineer', 'testing intern',
#        'junior technical writer', 'category manager', 'ai intern',
#        'database administrator - hà nội ta141',
#        'cloud engineer professional (kỹ sư phần mềm)', '.net developers',
#        'thực tập sinh .net/ c#',
#        'chuyên viên cao cấp vận hành ứng dụng (application support level 2)',
#        'back-end intern (ruby)', 'kỹ sư phần mềm r&d',
#        'qa engineer - chuyên viên bảo đảm chất lượng phần mềm',
#        'junior backend ruby ($700-$1000)',
#        'thực tập sinh testing (tiếng anh/ tiếng nhật)',
#        'senior backend', 'security administration',
#        'kỹ sư quản trị mạng & bảo mật',
#        'chuyên viên kỹ thuật vận hành (windows) - upto 30 triệu',
#        'junior network engineer',
#        'trưởng phòng system (upto 50m/16 tháng lương/năm + thưởng khác)',
#        'cộng tác viên mobile (flutter)', 'network engineer - fresher',
#        'fresher mathematics', 'qa engineer (manual/automation)',
#        'it fullstack', 'full-stack web development mentor-(part-time)',
#        'nhân viên giải pháp cntt', 'business intelligence analyst',
#        'nhân viên hỗ trợ triển khai phần mềm', '.net tech lead',
#        'cộng tác viên xử lý hình ảnh - (làm việc online - không yêu cầu kinh nghiệm)',
#        'nhân viên vận hành server (được đào tạo)',
#        'it business development - chuyên viên phát triển doanh nghiệp',
#        'lập trình backend', 'kỹ sư triển khai phần mềm',
#        'frontend team lead', 'marketing online',
#        'kỹ sư vận hành storage (storage engineer) upto 60 triệu/tháng',
#        'kỹ sư system administrator (key member system administrator)',
#        'senior frontend (hn/hcmc)', 'thực tập sinh c++',
#        'scrum master - msb df - dxk - 1m339', 'project techlead',
#        'chuyên viên cao cấp triển khai front-end - msb df - dxn - 1m343',
#        'nhân viên quản trị ứng dụng', 'thực tập it',
#        'database administrator - hcm',
#        'nhân viên triển khai dự án phần mềm',
#        'chuyên gia quản trị dữ liệu - msb df - dxa - 1m352',
#        'chuyên gia nền tảng dữ liệu phân tích - msb df - dxa - 1m350',
#        'kỹ thuật viên máy atm',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [17 hải bình thị trấn long hải, huyện long điền, tỉnh bà rịa - vũng tàu]',
#        'chuyên viên cao cấp khoa học dữ liệu - msb df - dxa - 1m353',
#        'senior cloud engineer (thu nhập upto 2000$)',
#        'nhân viên sáng tạo nội dung',
#        'nhân viên kỹ thuật (âm thanh, ánh sáng,sự kiện) thu nhập từ 8-15 triệu',
#        'game server (c#)', 'chuyên viên phát triển sản phẩm mảng coding',
#        'graphic designer', 'thiết kế website',
#        'business unit director (n2, it)',
#        'system fresher (không yêu cầu kinh nghiệm)',
#        'chuyên viên giám sát - trực vận hành tier 1 - [cmc cyber security]',
#        'kiến trúc sư trưởng dự án (project tech lead)',
#        'nhân viên hỗ trợ kỹ thuật sản phẩm apple [ f.studio đường 30/4, tp. vũng tàu - brvt]',
#        'nhân viên hỗ trợ kỹ thuật sản phẩm apple [f.studio phước bửu, xuyên mộc - brvt]',
#        'nhân viên trực vận hành hệ thống', 'golang (tts/fresher)',
#        'kỹ sư an toàn thông tin (information technology security)',
#        'kỹ sư giám sát công trình kỹ thuật điện nhẹ', 'blockchain lead',
#        'nlp engineer (mid-senior)', 'comtor', 'truyền thông',
#        'helpdesk (japanese)_day shift', 'kỹ sư bảo trì hệ thống sfc',
#        'it network engineer tại hà nội (8m - 14m)',
#        'chuyên viên cntt khai thác tài nguyên mạng',
#        'kỹ sư cntt nghiên cứu và phát triển tài nguyên trên internet',
#        'kỹ sư phần mềm nhúng fresher (up to 1200$)',
#        'kỹ sư phần mềm nhúng senior (up to 1500$)', 'senior .net',
#        'technical leader - hcm',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ an phước - long thành - đồng nai ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ chợ mới long thành - long thành - đồng nai ]',
#        'nhân viên hỗ trợ kỹ thuật đtdđ/laptop [ phước thái - long thành - đồng nai ]',
#        'junior mobile dev', ' junior fullstack (golang, typescript)',
#        'technical writer', 'kỹ sư lập trình nhúng',
#        'giảng viên it - fai - (fpt education)',
#        'trưởng bộ phận lập trình mobile', 'it risk management',
#        'data quality specialist - t10053', 'scrum master - t10052'],
#       dtype=object)

# %% [markdown]
# Các từ khoá để phân loại

# %%
software = ['developer','java','python','.net','phần mềm','android','software',
                'js','ruby on rails','lập trình','ứng dụng','end','mobile','react native',
                'unity','coder','ios','angular','c/c++','web','app','golang','embedded','flutter',
                ]
product_business = ['business','product']
manage = ['manager','lead','trưởng','management']
design = ['design','thiết kế']
security = ['an ninh','security','an toàn']
helpdesk = ['help','hỗ trợ','support','desk']
testing = ['test','qc','kiểm thử','qa','quality control']
infrastructure = ['system','hệ thống','mạng','devops','dev ops','administrator','server','quản trị']
data_ai = ['data','dữ liệu','ai','cloud','trí tuệ','computer']

# %% [markdown]
# Kiểm tra title chứa từ khoá nào thì phân loại vào mục đó

# %%
def category_it(title):
    if any(d in title for d in design):
        return 'Design'
    elif any(m in title for m in manage):
        return 'Management'
    elif any(p in title for p in product_business):
        return 'Product and Business'
    elif any(s in title for s in security):
        return 'Security'
    elif any(h in title for h in helpdesk):
        return 'Help Desk'
    elif any(t in title for t in testing):
        return 'Testing'
    elif any(i in title for i in infrastructure):
        return 'Infrastructure'
    elif any(d in title for d in data_ai):
        return 'Data & Ai'
    elif any(s in title for s in software):
        return 'Software'
    return 'Khac'

# %%
temp_df['Loai'] = temp_df['Title'].apply(category_it)

# %% [markdown]
# Tiếp đến, ta phân loại khu vực dựa trên địa chỉ, ta phân loại các khu vực sau:
# - Hà Nội
#
# - Đà Nẵng
#
# - Hồ Chí Minh
#
# - Khác

# %%
temp_df['DiaChi'].unique()
# Out:
# array(['Cầu Giấy,Hà Nội', 'Hà Nội,Cầu Giấy,Thạch Thất',
#        'Vĩnh Phúc,TP Vĩnh Yên', 'Hà Nội,Nam Từ Liêm',
#        'Hồ Chí Minh,Quận 10', 'Hà Nội', 'Hà Nội,Đống Đa',
#        'Hồ Chí Minh,Tân Bình', 'Hà Nội,Cầu Giấy', 'Nghệ An,TP Vinh',
#        'Nam Từ Liêm,Hà Nội', 'Hà Nội,Ba Đình',
#        'Hà Nội,Hồ Chí Minh,Bình Dương,Bắc Ninh,Đồng Nai,Hưng Yên,Hải Dương,Đà Nẵng,Hải Phòng,Bình Thuận,An Giang,Bắc Kạn,Bà Rịa-Vũng Tàu,Bắc Giang,Cà Mau,Bạc Liêu,Bến Tre,Bình Định,Bình Phước,Cao Bằng,Điện Biên,Cần Thơ,Đồng Tháp,Hà Giang,Gia Lai,Cửu Long,Đắk Lắk,Đắc Nông,Hà Nam,Hậu Giang,Kiên Giang,Hà Tĩnh,Lâm Đồng,Kon Tum,Hoà Bình,Khánh Hoà,Lai Châu,Lạng Sơn,Long An,Nam Định,Nghệ An,Lào Cai,Ninh Bình,Phú Thọ,Phú Yên,Quảng Bình,Quảng Nam,Quảng Ngãi,Ninh Thuận,Quảng Trị,Thanh Hoá,Quảng Ninh,Sơn La,Tây Ninh,Thái Bình,Thái Nguyên,Thừa Thiên Huế,Tiền Giang,Tuyên Quang,Sóc Trăng,Trà Vinh,Vĩnh Phúc,Vĩnh Long',
#        'Hà Nội,Hoàn Kiếm',
#        'Hà Nội,Đống Đa,Đà Nẵng,Sơn Trà,Hồ Chí Minh,Gò Vấp',
#        'Hồ Chí Minh,Quận 1', 'Hà Đông,Hà Nội',
#        'Cầu Giấy,Hoàng Mai,Cẩm Lệ,Hà Nội,Đà Nẵng', 'Hồ Chí Minh,Quận 7',
#        'Tân Bình,Hồ Chí Minh', 'Thạch Thất,Hà Nội', 'Hồ Chí Minh',
#        'Cầu Giấy,Hoàng Mai,Hà Nội', 'Hồ Chí Minh,Quận 3',
#        'Hà Nội,Thanh Xuân', 'Thủ Đức,Hồ Chí Minh', 'Hà Nội,Hai Bà Trưng',
#        'Đống Đa,Hà Nội', 'Hà Nội,Gia Lâm', 'Hồ Chí Minh,Quận 2',
#        'Hồ Chí Minh,Quận 3,Hà Nội,Hai Bà Trưng', 'Hà Nội,Đông Anh',
#        'Hà Nội,Từ Liêm', 'Hà Nội,Cầu Giấy,Hồ Chí Minh,Quận 7',
#        'Hà Nội,Thanh Trì', 'Hà Nội,Thạch Thất', 'Hồ Chí Minh,Bình Thạnh',
#        'Hà Nội,Hà Đông', 'Đắk Lắk,TP Buôn Ma Thuột', 'Hà Nam,Duy Tiên',
#        'Cần Thơ,Ninh Kiều', 'Hồ Chí Minh,Hà Nội',
#        'Hồ Chí Minh,Gò Vấp,Quận 1,Tân Phú,Thủ Đức,Tân Bình,Bình Thạnh',
#        'Đồng Nai', 'Hà Nội,Cầu Giấy,Đống Đa',
#        'Hà Nội,Cầu Giấy,Thanh Hoá,TP Thanh Hoá', 'Thanh Hoá,TP Thanh Hoá',
#        'Hải Dương,Cẩm Giàng', 'Hồ Chí Minh,Gò Vấp', 'Kiên Giang,Phú Quốc',
#        'Hồ Chí Minh,Tân Bình,Đà Nẵng,Thanh Khê', 'Hồ Chí Minh,Phú Nhuận',
#        'Hà Nội,Cầu Giấy,Thanh Xuân', 'Thừa Thiên Huế,TP Huế',
#        'Nước Ngoài', 'Hồ Chí Minh,Quận 9', 'Đồng Nai,Biên Hoà',
#        'Đồng Nai,Tân Phú', 'Bình Thuận,Bắc Bình', 'Bình Thuận,Phan Thiết',
#        'Bình Thuận,Tuy Phong', 'Hà Nội,Mê Linh',
#        'Hồ Chí Minh,Tân Bình,Hà Nội,Ba Đình', 'Hà Nội,Hồ Chí Minh',
#        'Hồ Chí Minh,Tân Bình,Thừa Thiên Huế,TP Huế',
#        'Hồ Chí Minh,Quận 12', 'Hồ Chí Minh,Bình Thạnh,Hà Nội,Cầu Giấy',
#        'Hà Nội,Hoàng Mai', 'Hồ Chí Minh,Quận 4', 'Hà Nội,Bắc Từ Liêm',
#        'Tây Ninh,Trảng Bàng', 'Đà Nẵng,Ngũ Hành Sơn',
#        'Đồng Nai,Nhơn Trạch', 'Bình Thuận,Hàm Thuận Nam',
#        'Đồng Nai,Vĩnh Cửu', 'Hồ Chí Minh,Phú Nhuận,Đà Nẵng,Thanh Khê',
#        'Hồ Chí Minh,Bình Dương', 'Hải Phòng,Ngô Quyền',
#        'Hồ Chí Minh,Quận 4,Quận 10', 'Hồ Chí Minh,Tân Phú',
#        'Gò Vấp,Hồ Chí Minh', 'Quảng Ninh,Đầm Hà',
#        'Hồ Chí Minh,Quận 1,Phú Nhuận', 'Hà Nội,Hồ Chí Minh,Đà Nẵng',
#        'Đà Nẵng', 'Hồ Chí Minh,Thủ Đức', 'Hồ Chí Minh,Đà Nẵng',
#        'Hồ Chí Minh,Đà Nẵng,Hải Châu',
#        'Hà Nội,Thanh Xuân,Hồ Chí Minh,Quận 1', 'Đà Nẵng,Hải Châu',
#        'Hà Nội,Hồ Chí Minh,Quận 1,Thanh Xuân',
#        'Hà Nội,Hoàn Kiếm,Cầu Giấy,Thạch Thất',
#        'Kiên Giang,Phú Quốc,Đồng Nai,Long Thành',
#        'Hồ Chí Minh,Thủ Đức,Đà Nẵng,Ngũ Hành Sơn',
#        'TP Nha Trang,Khánh Hoà', 'Hồ Chí Minh,Quận 11',
#        'Hồng Bàng,Hải Phòng', 'Hồ Chí Minh,Quận 8',
#        'TP Bắc Ninh,Bắc Ninh', 'Hà Nội,Tây Hồ', 'Bình Dương,Bắc Tân Uyên',
#        'Hà Nội,Đống Đa,Nam Từ Liêm', 'Đà Nẵng,Cẩm Lệ',
#        'Quận 5,Hồ Chí Minh', 'Hồ Chí Minh,Quận 12,Phú Nhuận',
#        'Hồ Chí Minh,Bình Thạnh,Đà Nẵng,Cẩm Lệ', 'Đà Nẵng,Sơn Trà',
#        'Bình Định,TP Quy Nhơn', 'Đắk Lắk',
#        'Gia Lai,TP Pleiku,Hồ Chí Minh', 'Khánh Hoà,TP Nha Trang',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Gò Vấp', 'Toàn Quốc',
#        'Hà Nội,Long Biên', 'Bà Rịa-Vũng Tàu,Phú Mỹ',
#        'Hà Nội,Hai Bà Trưng,Thừa Thiên Huế,Phú Vang',
#        'Hồ Chí Minh,Tân Bình,Lâm Đồng,TP Đà Lạt',
#        'Hà Nội,Nam Từ Liêm,Hồ Chí Minh,Thủ Đức', 'Sóc Trăng,Châu Thành',
#        'Hồ Chí Minh,Hóc Môn', 'Bình Thuận,Hàm Tân', 'Bình Thuận,Đức Linh',
#        'Bình Thuận,Hàm Thuận Bắc', 'Hồ Chí Minh,Bình Tân',
#        'Thanh Xuân,Hà Nội', 'Đồng Nai,Định Quán',
#        'Đống Đa,Quận 1,Hà Nội,Hồ Chí Minh',
#        'Hồ Chí Minh,Gò Vấp,Hà Nội,Đống Đa,Đà Nẵng,Sơn Trà',
#        'Hà Nội,Thạch Thất,Cầu Giấy',
#        'Đà Nẵng,Thanh Khê,Hồ Chí Minh,Quận 1', 'Đà Nẵng,Thanh Khê',
#        'Hà Nội,Thanh Xuân,Hoàn Kiếm',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Quận 1',
#        'Hồ Chí Minh,Đà Nẵng,Thanh Khê', 'Đồng Nai,Long Thành',
#        'Hồ Chí Minh,Quận 4,Hà Nội,Thanh Xuân', 'Quảng Ngãi,TP Quảng Ngãi',
#        'Hà Nội,Hai Bà Trưng,Đà Nẵng,Thanh Khê',
#        'Hồ Chí Minh,Quận 12,Hà Nội,Thanh Xuân',
#        'Hồ Chí Minh,Quận 7,Hà Nội,Nam Từ Liêm', 'Bình Dương,Bàu Bàng',
#        'Quận 1,Hồ Chí Minh', 'Hồ Chí Minh,Quận 5', 'Vĩnh Long',
#        'Bình Dương,Thủ Dầu Một', 'Bà Rịa-Vũng Tàu,TP Vũng Tàu',
#        'Bà Rịa-Vũng Tàu,Đất Đỏ', 'Hà Nội,Ba Đình,Hồ Chí Minh,Tân Bình',
#        'Hải Châu,TP Huế,Đà Nẵng,Thừa Thiên Huế',
#        'Thừa Thiên Huế,Đà Nẵng,TP Huế,Hải Châu',
#        'Hồ Chí Minh,Quận 3,Bình Thạnh', 'Bình Định,Phù Cát',
#        'Bà Rịa-Vũng Tàu,Xuyên Mộc', 'Hồ Chí Minh,Quận 6',
#        'Hà Nội,Hồ Chí Minh,Tân Bình', 'Cần Thơ', 'Ba Đình,Hà Nội',
#        'Hà Nội,Hoàng Mai,Thanh Xuân',
#        'Hà Nội,Nam Từ Liêm,Cầu Giấy,Hoàng Mai',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Thủ Đức',
#        'Hồ Chí Minh,Quận 4,Thủ Đức',
#        'Hà Nội,Thanh Xuân,Hồ Chí Minh,Phú Nhuận,Đà Nẵng,Hải Châu',
#        'Hà Nội,Hai Bà Trưng,Hồ Chí Minh,Bình Thạnh',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Quận 3',
#        'Hà Nội,Nam Từ Liêm,Hồ Chí Minh,Tân Bình,Thừa Thiên Huế,TP Huế',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Bình Thạnh',
#        'Hồ Chí Minh,Gò Vấp,Đà Nẵng,Sơn Trà,Hà Nội,Đống Đa',
#        'Hồ Chí Minh,Quận 4,Đà Nẵng,Hải Châu',
#        'Đà Nẵng,Thanh Khê,Hồ Chí Minh,Quận 1,Hà Nội,Cầu Giấy',
#        'Kiên Giang,TP Rạch Giá', 'Hà Nội,Cầu Giấy,Hồ Chí Minh,Quận 4',
#        'Hà Nội,Cầu Giấy,Nam Từ Liêm', 'Bắc Ninh,Từ Sơn',
#        'Quận 7,Hồ Chí Minh', 'An Giang,Châu Thành',
#        'Hà Nội,Đống Đa,Hồ Chí Minh,Gò Vấp',
#        'Hà Nội,Thanh Xuân,Đà Nẵng,Thanh Khê',
#        'Hà Nội,Thanh Xuân,Hồ Chí Minh,Quận 4',
#        'Lâm Đồng,TP Đà Lạt,Lạc Dương,Đức Trọng,Đơn Dương',
#        'Hồ Chí Minh,Bình Thạnh,Hà Nội', 'Hồ Chí Minh,Bình Chánh',
#        'Cầu Giấy,Quận 7,Hà Nội,Hồ Chí Minh',
#        'Đà Nẵng,Hải Châu,Hà Nội,Cầu Giấy',
#        'Nước Ngoài,Hồ Chí Minh,Hà Nội',
#        'Hồ Chí Minh,Quận 1,Hà Nội,Cầu Giấy', 'Hà Nội,Đống Đa,Thanh Xuân',
#        'Hà Nội,Đống Đa,Hồ Chí Minh,Gò Vấp,Đà Nẵng,Sơn Trà',
#        'Hồ Chí Minh,Tân Bình,Đà Nẵng,Hải Châu',
#        'Đà Nẵng,Hải Châu,Hồ Chí Minh,Tân Bình',
#        'Hồ Chí Minh,Quận 5,Tân Bình', 'Bắc Ninh,Từ Sơn,Hà Nội,Đông Anh',
#        'Hà Nội,Bắc Từ Liêm,Hồ Chí Minh,Quận 1',
#        'Hà Nội,Bắc Từ Liêm,Hồ Chí Minh,Phú Nhuận',
#        'Hồ Chí Minh,Quận 6,Long An,Cần Giuộc',
#        'Long An,Cần Giuộc,Hồ Chí Minh,Quận 6',
#        'Hồ Chí Minh,Hà Nội,Nam Từ Liêm',
#        'Hà Nội,Cầu Giấy,Đà Nẵng,Hải Châu,Hồ Chí Minh,Quận 1',
#        'Phú Yên,TP Tuy Hoà',
#        'Hải Châu,Thanh Khê,Sơn Trà,Ngũ Hành Sơn,Liên Chiểu,Hòa Vang,Cẩm Lệ,Hoàng Sa,Đà Nẵng',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Quận 9,Đà Nẵng,Ngũ Hành Sơn',
#        'Hồ Chí Minh,Thủ Đức,Bình Dương,Bến Cát',
#        'Hồ Chí Minh,Tân Phú,Bắc Ninh,Từ Sơn',
#        'Đồng Nai,Long Thành,Sóc Trăng,Hồ Chí Minh,Thủ Đức,Cần Thơ,Ninh Kiều',
#        'Bình Dương,Thuận An', 'Hà Nội,Cầu Giấy,Đà Nẵng,Hải Châu',
#        'Hồ Chí Minh,Bình Thạnh,Hà Nội,Cầu Giấy,Đà Nẵng,Cẩm Lệ',
#        'Ninh Bình,Gia Viễn', 'Đà Nẵng,Ngũ Hành Sơn,Nước Ngoài',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Bình Thạnh,Quận 7',
#        'Hồ Chí Minh,Tân Bình,Hà Nội,Đống Đa,Quảng Ninh,Phú Thọ',
#        'Bà Rịa-Vũng Tàu,Long Điền', 'Quận 3,Hồ Chí Minh',
#        'Hà Nội,Hoàn Kiếm,Thạch Thất', 'Bình Phước',
#        'Tiền Giang,Cái Bè,Kiên Giang,Phú Quốc,Long An,Đức Hoà',
#        'Long An,Cần Giuộc',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Quận 10,Đà Nẵng,Thanh Khê,Cần Thơ,Ninh Kiều',
#        'Hà Nội,Nam Từ Liêm,Đà Nẵng', 'Hà Nội,Đống Đa,Cầu Giấy',
#        'Hồ Chí Minh,Quận 4,Hà Nội,Đống Đa',
#        'Hà Nội,Hồ Chí Minh,Đà Nẵng,Thừa Thiên Huế',
#        'Hà Nội,Cầu Giấy,Hồ Chí Minh,Quận 9', 'Hà Nội,Hoài Đức,Cầu Giấy',
#        'Hà Nội,Thanh Xuân,Nam Từ Liêm', 'Hà Nội,Cầu Giấy,Gia Lâm'],
#       dtype=object)

# %%
def set_location(location):
    if 'Hà Nội' in location and 'Hồ Chí Minh' in location and 'Đà Nẵng' in location:
        return 'Cả 3'
    elif 'Hà Nội' in location and 'Hồ Chí Minh' in location:
        return 'hn-hcm'
    elif 'Hà Nội' in location and 'Đà Nẵng' in location:
        return 'hn-dn'
    elif 'Hồ Chí Minh' in location and 'Đà Nẵng' in location:
        return 'hcm-dn'
    elif 'Hà Nội' in location:
        return 'hn'
    elif 'Đà Nẵng' in location:
        return 'dn'
    elif 'Hồ Chí Minh' in location:
        return 'hcm'
    return 'Khác'

# %%
temp_df['KhuVuc'] = temp_df['DiaChi'].apply(set_location)

# %% [markdown]
# Tiếp đến, ta tính số lượng bài đăng theo từng khu vực

# %%
hn_job = temp_df[(temp_df['KhuVuc'] == 'hn') | (temp_df['KhuVuc'] == 'hn-dn') | ((temp_df['KhuVuc'] == 'hn-hcm')) | (temp_df['KhuVuc'] == 'Cả 3')]['Loai'].value_counts()
dn_job = temp_df[(temp_df['KhuVuc'] == 'dn') | (temp_df['KhuVuc'] == 'hn-dn') | ((temp_df['KhuVuc'] == 'hcm-dn'))| (temp_df['KhuVuc'] == 'Cả 3')]['Loai'].value_counts()
hcm_job = temp_df[(temp_df['KhuVuc'] == 'hcm') | (temp_df['KhuVuc'] == 'hcm-dn') | ((temp_df['KhuVuc'] == 'hn-hcm'))| (temp_df['KhuVuc'] == 'Cả 3')]['Loai'].value_counts()
other_job = temp_df[(temp_df['KhuVuc'] == 'Khác')]['Loai'].value_counts()

# %% [markdown]
# Vẽ biểu đồ để biểu thị số lượng bài tuyển theo các khu vực

# %%
fig,ax = plt.subplots(2,2,figsize = (15,10))

ax[0,0].barh(hn_job.index,hn_job.values)
ax[0,0].set_title('Số lượng bài tuyển khu vực Hà Nội')
ax[0,0].set(xlabel='Số lượng', ylabel='Lĩnh vực')

ax[0,1].barh(dn_job.index,dn_job.values)
ax[0,1].set_title('Số lượng bài tuyển khu vực Đà Nẵng')
ax[0,1].set(xlabel='Số lượng', ylabel='Lĩnh vực')

ax[1,0].barh(hcm_job.index,hcm_job.values)
ax[1,0].set_title('Số lượng bài tuyển khu vực Hồ Chí Minh')
ax[1,0].set(xlabel='Số lượng', ylabel='Lĩnh vực')

ax[1,1].barh(other_job.index,other_job.values)
ax[1,1].set_title('Số lượng bài tuyển khu vực khác')
ax[1,1].set(xlabel='Số lượng', ylabel='Lĩnh vực')

plt.show()

# %% [markdown]
# Ở 3 khu vực lớn là Hà Nội, Đà Nẵng, tp HCM, nhu cầu tuyển dụng software là cao vượt trội so với các ngành nghề khác. Chứng tỏ đây là lĩnh vực trọng yếu của các khu vực này. Theo sau đó là các ngành nghề như Testing,Infrastructure... Tuy nhiêu, ở những nơi khác, nhu cầu tuyển dụng software lại không cao bằng mà chủ yếu tuyển công việc hỗ trợ như là HelpDesk. Hà Nội có số bài đăng tuyển dụng vượt trội so với các nơi khác.

# %% [markdown]
# Tiếp theo ta tính lương trung bình của từng ngành nghề theo các khu vực, ta sẽ loại bỏ đi những dòng không có lương để dễ tính

# %%
temp_df.dropna(subset=['Salary'],inplace = True)

# %%
temp_df['Salary']
# Out:
# 0          (1200, 1400)
# 3       (600.0, 1200.0)
# 5            (600, 700)
# 6            (600, 800)
# 8          (1600, 1800)
#              ...
# 2330     (400.0, 600.0)
# 2331       (1300, 1500)
# 2332         (600, 700)
# 2333     (400.0, 800.0)
# 2334       (1800, 2000)
# Name: Salary, Length: 1571, dtype: object

# %%
def convert_list(sal):
    sal = sal.replace('(','')
    sal = sal.replace(')','')
    return list(map(float,sal.split(',')))

# %%
temp_df['Salary'] = temp_df['Salary'].apply(convert_list)

# %%
def avesalary(salary):
    return (int(salary[0])+int(salary[1]))/2

# %%
temp_df['AveSal'] = temp_df['Salary'].apply(avesalary)

# %%
temp_df.groupby(['KhuVuc','Loai'])['AveSal'].mean()
# Out:
# KhuVuc  Loai
# Cả 3    Data & Ai                340.000000
#         Khac                     440.000000
#         Software                1980.000000
# Khác    Data & Ai                170.000000
#         Design                   495.000000
#         Help Desk                386.666667
#         Infrastructure           930.000000
#         Khac                     426.153846
#         Software                 503.125000
#         Testing                  466.666667
# dn      Help Desk                160.000000
#         Infrastructure          1900.000000
#         Khac                     630.000000
#         Software                1420.000000
# hcm     Data & Ai                801.000000
#         Design                   700.000000
#         Help Desk                609.166667
#         Infrastructure          1106.153846
#         Khac                     525.538462
#         Management              1759.090909
#         Product and Business     760.000000
#         Security                1100.000000
#         Software                1102.729885
#         Testing                  815.000000
# hcm-dn  Software                1682.142857
#         Testing                 1900.000000
# hn      Data & Ai                908.536585
#         Design                   943.333333
#         Help Desk                438.125000
#         Infrastructure           957.023810
#         Khac                     744.969325
#         Management              1662.058824
#         Product and Business    1107.428571
#         Security                1133.750000
#         Software                1067.337770
#         Testing                  733.205128
# hn-dn   Data & Ai               2400.000000
#         Khac                    2400.000000
#         Software                1050.000000
# hn-hcm  Data & Ai               1060.000000
#         Infrastructure          1400.000000
#         Khac                     548.750000
#         Management              1750.000000
#         Software                1070.000000
#         Testing                 1166.666667
# Name: AveSal, dtype: float64

# %% [markdown]
# Chọn các khu vực ra

# %%
hn_sal = temp_df[(temp_df['KhuVuc'] == 'hn') | (temp_df['KhuVuc'] == 'hn-dn') | ((temp_df['KhuVuc'] == 'hn-hcm')) | (temp_df['KhuVuc'] == 'Cả 3')]
dn_sal = temp_df[(temp_df['KhuVuc'] == 'dn') | (temp_df['KhuVuc'] == 'hn-dn') | ((temp_df['KhuVuc'] == 'hcm-dn'))| (temp_df['KhuVuc'] == 'Cả 3')]
hcm_sal = temp_df[(temp_df['KhuVuc'] == 'hcm') | (temp_df['KhuVuc'] == 'hcm-dn') | ((temp_df['KhuVuc'] == 'hn-hcm'))| (temp_df['KhuVuc'] == 'Cả 3')]
other_sal = temp_df[(temp_df['KhuVuc'] == 'Khác')]

# %% [markdown]
# Gom nhóm và tính lương

# %%
hn_sal = hn_sal.groupby(['Loai'])['AveSal'].mean()
dn_sal = dn_sal.groupby(['Loai'])['AveSal'].mean()
hcm_sal = hcm_sal.groupby(['Loai'])['AveSal'].mean()
other_sal = other_sal.groupby(['Loai'])['AveSal'].mean()

# %% [markdown]
# Biểu thị lương trung bình theo các khu vực

# %%
fig,ax = plt.subplots(2,2,figsize = (15,10))

ax[0,0].barh(hn_sal.index,hn_sal.values)
ax[0,0].set_title('Mức lương trung bình khu vực Hà Nội')
ax[0,0].set(xlabel='Lương($)', ylabel='Lĩnh vực')

ax[0,1].barh(dn_sal.index,dn_sal.values)
ax[0,1].set_title('Mức lương trung bình khu vực Đà Nẵng')
ax[0,1].set(xlabel='Lương($)', ylabel='Lĩnh vực')

ax[1,0].barh(hcm_sal.index,hcm_sal.values)
ax[1,0].set_title('Mức lương trung bình khu vực Hồ Chí Minh')
ax[1,0].set(xlabel='Lương($)', ylabel='Lĩnh vực')

ax[1,1].barh(other_sal.index,other_sal.values)
ax[1,1].set_title('Mức lương trung bình khu vực khác')
ax[1,1].set(xlabel='Lương($)', ylabel='Lĩnh vực')

plt.show()

# %% [markdown]
# Những khu vực vào có ngành Manage thì lương của ngành này sẽ là cao nhất. Đơn giản là đây là ngành có cấp bậc cao, đòi hỏi năng lực lãnh đạo. Một số ngành đặc thù tuyển ít nên có mức lương cao như Infrastructure, security. Software là ngành tuyển nhiều nhất cũng có mức lương khá ổn khi nằm ở trung bình trên. Khá bất ngờ là ngành hot như Data & AI lại không có mức lương cao lắm, thậm chí nhu cầu tuyển dụng cũng không quá nhiều
